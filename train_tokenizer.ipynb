# %%
"""
以下代码复制于 https://github.com/karpathy/minbpe
我简化了以下，放在一个文件里方便演示。
如果真正产品化使用去训练自己的tokenizer，建议直接用上面的Github，把RegexTokenizer的类也加进去。
"""
import unicodedata
import os
import time
# -----------------------------------------------------------------------------
# a few helper functions useful for both BasicTokenizer and RegexTokenizer

def get_stats(ids, counts=None):
    """
    Given a list of integers, return a dictionary of counts of consecutive pairs
    Example: [1, 2, 3, 1, 2] -> {(1, 2): 2, (2, 3): 1, (3, 1): 1}
    Optionally allows to update an existing dictionary of counts
    """
    counts = {} if counts is None else counts
    for pair in zip(ids, ids[1:]):  # iterate consecutive elements
        counts[pair] = counts.get(pair, 0) + 1
    return counts


def merge(ids, pair, idx):
    """
    In the list of integers (ids), replace all consecutive occurrences
    of pair with the new integer token idx
    Example: ids=[1, 2, 3, 1, 2], pair=(1, 2), idx=4 -> [4, 3, 4]
    """
    newids = []
    i = 0
    while i < len(ids):
        # if not at the very last position AND the pair matches, replace it
        if ids[i] == pair[0] and i < len(ids) - 1 and ids[i + 1] == pair[1]:
            newids.append(idx)
            i += 2
        else:
            newids.append(ids[i])
            i += 1
    return newids


# first two helper functions...
def replace_control_characters(s: str) -> str:
    # we don't want to print control characters
    # which distort the output (e.g. \n or much worse)
    # https://stackoverflow.com/questions/4324790/removing-control-characters-from-a-string-in-python/19016117#19016117
    # http://www.unicode.org/reports/tr44/#GC_Values_Table
    chars = []
    for ch in s:
        if unicodedata.category(ch)[0] != "C":
            chars.append(ch)  # this character is ok
        else:
            chars.append(f"\\u{ord(ch):04x}")  # escape
    return "".join(chars)


def render_token(t: bytes) -> str:
    # pretty print a token, escaping control characters
    s = t.decode('utf-8', errors='replace')
    s = replace_control_characters(s)
    return s


# -----------------------------------------------------------------------------
# the base Tokenizer class

class Tokenizer:
    """Base class for Tokenizers"""

    def __init__(self):
        # default: vocab size of 256 (all bytes), no merges, no patterns
        self.merges = {}  # (int, int) -> int
        self.pattern = ""  # str
        self.special_tokens = {}  # str -> int, e.g. {'<|endoftext|>': 100257}
        self.vocab = self._build_vocab()  # int -> bytes

    def train(self, text, vocab_size, verbose=False):
        # Tokenizer can train a vocabulary of size vocab_size from text
        raise NotImplementedError

    def encode(self, text):
        # Tokenizer can encode a string into a list of integers
        raise NotImplementedError

    def decode(self, ids):
        # Tokenizer can decode a list of integers into a string
        raise NotImplementedError

    def _build_vocab(self):
        # vocab is simply and deterministically derived from merges
        vocab = {idx: bytes([idx]) for idx in range(256)}
        for (p0, p1), idx in self.merges.items():
            vocab[idx] = vocab[p0] + vocab[p1]
        for special, idx in self.special_tokens.items():
            vocab[idx] = special.encode("utf-8")
        return vocab

    def save(self, file_prefix):
        """
        Saves two files: file_prefix.vocab and file_prefix.model
        This is inspired (but not equivalent to!) sentencepiece's model saving:
        - model file is the critical one, intended for load()
        - vocab file is just a pretty printed version for human inspection only
        """
        # write the model: to be used in load() later
        model_file = file_prefix + ".model"
        with open(model_file, 'w') as f:
            # write the version, pattern and merges, that's all that's needed
            f.write("minbpe v1\n")
            f.write(f"{self.pattern}\n")
            # write the special tokens, first the number of them, then each one
            f.write(f"{len(self.special_tokens)}\n")
            for special, idx in self.special_tokens.items():
                f.write(f"{special} {idx}\n")
            # the merges dict
            for idx1, idx2 in self.merges:
                f.write(f"{idx1} {idx2}\n")
        # write the vocab: for the human to look at
        vocab_file = file_prefix + ".vocab"
        inverted_merges = {idx: pair for pair, idx in self.merges.items()}
        with open(vocab_file, "w", encoding="utf-8") as f:
            for idx, token in self.vocab.items():
                # note: many tokens may be partial utf-8 sequences
                # and cannot be decoded into valid strings. Here we're using
                # errors='replace' to replace them with the replacement char �.
                # this also means that we couldn't possibly use .vocab in load()
                # because decoding in this way is a lossy operation!
                s = render_token(token)
                # find the children of this token, if any
                if idx in inverted_merges:
                    # if this token has children, render it nicely as a merge
                    idx0, idx1 = inverted_merges[idx]
                    s0 = render_token(self.vocab[idx0])
                    s1 = render_token(self.vocab[idx1])
                    f.write(f"[{s0}][{s1}] -> [{s}] {idx}\n")
                else:
                    # otherwise this is leaf token, just print it
                    # (this should just be the first 256 tokens, the bytes)
                    f.write(f"[{s}] {idx}\n")

    def load(self, model_file):
        """Inverse of save() but only for the model file"""
        assert model_file.endswith(".model")
        # read the model file
        merges = {}
        special_tokens = {}
        idx = 256
        with open(model_file, 'r', encoding="utf-8") as f:
            # read the version
            version = f.readline().strip()
            assert version == "minbpe v1"
            # read the pattern
            self.pattern = f.readline().strip()
            # read the special tokens
            num_special = int(f.readline().strip())
            for _ in range(num_special):
                special, special_idx = f.readline().strip().split()
                special_tokens[special] = int(special_idx)
            # read the merges
            for line in f:
                idx1, idx2 = map(int, line.split())
                merges[(idx1, idx2)] = idx
                idx += 1
        self.merges = merges
        self.special_tokens = special_tokens
        self.vocab = self._build_vocab()


class BasicTokenizer(Tokenizer):

    def __init__(self):
        super().__init__()

    def train(self, text, vocab_size, verbose=False):
        assert vocab_size >= 256
        num_merges = vocab_size - 256

        # input text preprocessing
        text_bytes = text.encode("utf-8")  # raw bytes
        ids = list(text_bytes)  # list of integers in range 0..255

        # iteratively merge the most common pairs to create new tokens
        merges = {}  # (int, int) -> int
        vocab = {idx: bytes([idx]) for idx in range(256)}  # int -> bytes
        for i in range(num_merges):
            # count up the number of times every consecutive pair appears
            stats = get_stats(ids)
            # find the pair with the highest count
            pair = max(stats, key=stats.get)
            # mint a new token: assign it the next available id
            idx = 256 + i
            # replace all occurrences of pair in ids with idx
            ids = merge(ids, pair, idx)
            # save the merge
            merges[pair] = idx
            vocab[idx] = vocab[pair[0]] + vocab[pair[1]]
            # prints
            if verbose:
                print(f"merge {i + 1}/{num_merges}: {pair} -> {idx} ({vocab[idx]}) had {stats[pair]} occurrences")

        # save class variables
        self.merges = merges  # used in encode()
        self.vocab = vocab  # used in decode()

    def decode(self, ids):
        # given ids (list of integers), return Python string
        text_bytes = b"".join(self.vocab[idx] for idx in ids)
        text = text_bytes.decode("utf-8", errors="replace")
        return text

    def encode(self, text):
        # given a string text, return the token ids
        text_bytes = text.encode("utf-8")  # raw bytes
        ids = list(text_bytes)  # list of integers in range 0..255
        while len(ids) >= 2:
            # find the pair with the lowest merge index
            stats = get_stats(ids)
            pair = min(stats, key=lambda p: self.merges.get(p, float("inf")))
            # subtle: if there are no more merges available, the key will
            # result in an inf for every single pair, and the min will be
            # just the first pair in the list, arbitrarily
            # we can detect this terminating case by a membership check
            if pair not in self.merges:
                break  # nothing else can be merged anymore
            # otherwise let's merge the best pair (lowest merge index)
            idx = self.merges[pair]
            ids = merge(ids, pair, idx)
        return ids



text = open("three_body_utf8.txt", "r", encoding="utf-8").read()

# create a directory for models, so we don't pollute the current directory
os.makedirs("models", exist_ok=True)

t0 = time.time()
# construct the Tokenizer object and kick off verbose training
tokenizer = BasicTokenizer()
tokenizer.train(text, 5256, verbose=True)  # 设置我们的字典长度为5256，即 vocab_size=5256，这里可以自己改动
# writes two files in the models directory: name.model, and name.vocab
prefix = os.path.join("models", "three-body-problem")
tokenizer.save(prefix)
t1 = time.time()

print(f"Training took {t1 - t0:.2f} seconds")


# load the model back
enc = BasicTokenizer()
enc.load("models/three-body-problem.model")
print(enc.encode("汪淼无奈地笑笑，第三次将黑球击入洞内。"))
print(enc.decode([464, 1990, 1331]))
# Out:
# merge 1/5000: (228, 184) -> 256 (b'\xe4\xb8') had 59301 occurrences
# merge 2/5000: (239, 188) -> 257 (b'\xef\xbc') had 54377 occurrences
# merge 3/5000: (257, 140) -> 258 (b'\xef\xbc\x8c') had 47290 occurrences
# merge 4/5000: (227, 128) -> 259 (b'\xe3\x80') had 44606 occurrences
# merge 5/5000: (231, 154) -> 260 (b'\xe7\x9a') had 37887 occurrences
# merge 6/5000: (260, 132) -> 261 (b'\xe7\x9a\x84') had 37538 occurrences
# merge 7/5000: (228, 186) -> 262 (b'\xe4\xba') had 27739 occurrences
# merge 8/5000: (259, 128) -> 263 (b'\xe3\x80\x80') had 23778 occurrences
# merge 9/5000: (228, 187) -> 264 (b'\xe4\xbb') had 22151 occurrences
# merge 10/5000: (226, 128) -> 265 (b'\xe2\x80') had 20660 occurrences
# merge 11/5000: (259, 130) -> 266 (b'\xe3\x80\x82') had 19387 occurrences
# merge 12/5000: (232, 191) -> 267 (b'\xe8\xbf') had 19367 occurrences
# merge 13/5000: (230, 152) -> 268 (b'\xe6\x98') had 18000 occurrences
# merge 14/5000: (229, 164) -> 269 (b'\xe5\xa4') had 17584 occurrences
# merge 15/5000: (229, 143) -> 270 (b'\xe5\x8f') had 17380 occurrences
# merge 16/5000: (229, 156) -> 271 (b'\xe5\x9c') had 16685 occurrences
# merge 17/5000: (230, 156) -> 272 (b'\xe6\x9c') had 15059 occurrences
# merge 18/5000: (256, 128) -> 273 (b'\xe4\xb8\x80') had 14952 occurrences
# merge 19/5000: (228, 189) -> 274 (b'\xe4\xbd') had 13696 occurrences
# merge 20/5000: (229, 136) -> 275 (b'\xe5\x88') had 12779 occurrences
# merge 21/5000: (268, 175) -> 276 (b'\xe6\x98\xaf') had 11930 occurrences
# merge 22/5000: (10, 263) -> 277 (b'\n\xe3\x80\x80') had 11889 occurrences
# merge 23/5000: (277, 263) -> 278 (b'\n\xe3\x80\x80\xe3\x80\x80') had 11889 occurrences
# merge 24/5000: (229, 144) -> 279 (b'\xe5\x90') had 11829 occurrences
# merge 25/5000: (271, 168) -> 280 (b'\xe5\x9c\xa8') had 10985 occurrences
# merge 26/5000: (262, 134) -> 281 (b'\xe4\xba\x86') had 10861 occurrences
# merge 27/5000: (229, 174) -> 282 (b'\xe5\xae') had 10749 occurrences
# merge 28/5000: (229, 133) -> 283 (b'\xe5\x85') had 10516 occurrences
# merge 29/5000: (230, 136) -> 284 (b'\xe6\x88') had 9324 occurrences
# merge 30/5000: (267, 153) -> 285 (b'\xe8\xbf\x99') had 9146 occurrences
# merge 31/5000: (229, 176) -> 286 (b'\xe5\xb0') had 8973 occurrences
# merge 32/5000: (228, 185) -> 287 (b'\xe4\xb9') had 8833 occurrences
# merge 33/5000: (265, 156) -> 288 (b'\xe2\x80\x9c') had 8760 occurrences
# merge 34/5000: (265, 157) -> 289 (b'\xe2\x80\x9d') had 8726 occurrences
# merge 35/5000: (232, 175) -> 290 (b'\xe8\xaf') had 8100 occurrences
# merge 36/5000: (272, 137) -> 291 (b'\xe6\x9c\x89') had 7908 occurrences
# merge 37/5000: (256, 170) -> 292 (b'\xe4\xb8\xaa') had 7826 occurrences
# merge 38/5000: (231, 187) -> 293 (b'\xe7\xbb') had 7770 occurrences
# merge 39/5000: (256, 141) -> 294 (b'\xe4\xb8\x8d') had 7725 occurrences
# merge 40/5000: (230, 151) -> 295 (b'\xe6\x97') had 7559 occurrences
# merge 41/5000: (131, 189) -> 296 (b'\x83\xbd') had 6905 occurrences
# merge 42/5000: (230, 157) -> 297 (b'\xe6\x9d') had 6839 occurrences
# merge 43/5000: (231, 148) -> 298 (b'\xe7\x94') had 6685 occurrences
# merge 44/5000: (262, 186) -> 299 (b'\xe4\xba\xba') had 6651 occurrences
# merge 45/5000: (258, 229) -> 300 (b'\xef\xbc\x8c\xe5') had 6415 occurrences
# merge 46/5000: (231, 156) -> 301 (b'\xe7\x9c') had 6399 occurrences
# merge 47/5000: (264, 150) -> 302 (b'\xe4\xbb\x96') had 6290 occurrences
# merge 48/5000: (229, 135) -> 303 (b'\xe5\x87') had 6199 occurrences
# merge 49/5000: (266, 278) -> 304 (b'\xe3\x80\x82\n\xe3\x80\x80\xe3\x80\x80') had 6129 occurrences
# merge 50/5000: (229, 190) -> 305 (b'\xe5\xbe') had 5980 occurrences
# merge 51/5000: (275, 176) -> 306 (b'\xe5\x88\xb0') had 5968 occurrences
# merge 52/5000: (230, 150) -> 307 (b'\xe6\x96') had 5932 occurrences
# merge 53/5000: (256, 173) -> 308 (b'\xe4\xb8\xad') had 5829 occurrences
# merge 54/5000: (229, 173) -> 309 (b'\xe5\xad') had 5807 occurrences
# merge 55/5000: (230, 137) -> 310 (b'\xe6\x89') had 5498 occurrences
# merge 56/5000: (256, 138) -> 311 (b'\xe4\xb8\x8a') had 5472 occurrences
# merge 57/5000: (264, 172) -> 312 (b'\xe4\xbb\xac') had 5391 occurrences
# merge 58/5000: (284, 145) -> 313 (b'\xe6\x88\x91') had 5203 occurrences
# merge 59/5000: (229, 141) -> 314 (b'\xe5\x8d') had 5195 occurrences
# merge 60/5000: (229, 138) -> 315 (b'\xe5\x8a') had 5003 occurrences
# merge 61/5000: (229, 183) -> 316 (b'\xe5\xb7') had 4933 occurrences
# merge 62/5000: (229, 188) -> 317 (b'\xe5\xbc') had 4854 occurrences
# merge 63/5000: (289, 278) -> 318 (b'\xe2\x80\x9d\n\xe3\x80\x80\xe3\x80\x80') had 4846 occurrences
# merge 64/5000: (229, 155) -> 319 (b'\xe5\x9b') had 4820 occurrences
# merge 65/5000: (231, 142) -> 320 (b'\xe7\x8e') had 4814 occurrences
# merge 66/5000: (271, 176) -> 321 (b'\xe5\x9c\xb0') had 4699 occurrences
# merge 67/5000: (233, 130) -> 322 (b'\xe9\x82') had 4643 occurrences
# merge 68/5000: (295, 182) -> 323 (b'\xe6\x97\xb6') had 4632 occurrences
# merge 69/5000: (233, 135) -> 324 (b'\xe9\x87') had 4616 occurrences
# merge 70/5000: (232, 174) -> 325 (b'\xe8\xae') had 4604 occurrences
# merge 71/5000: (231, 157) -> 326 (b'\xe7\x9d') had 4577 occurrences
# merge 72/5000: (269, 167) -> 327 (b'\xe5\xa4\xa7') had 4537 occurrences
# merge 73/5000: (228, 188) -> 328 (b'\xe4\xbc') had 4516 occurrences
# merge 74/5000: (297, 165) -> 329 (b'\xe6\x9d\xa5') had 4510 occurrences
# merge 75/5000: (230, 178) -> 330 (b'\xe6\xb2') had 4505 occurrences
# merge 76/5000: (322, 163) -> 331 (b'\xe9\x82\xa3') had 4482 occurrences
# merge 77/5000: (229, 191) -> 332 (b'\xe5\xbf') had 4467 occurrences
# merge 78/5000: (229, 165) -> 333 (b'\xe5\xa5') had 4405 occurrences
# merge 79/5000: (229, 134) -> 334 (b'\xe5\x86') had 4402 occurrences
# merge 80/5000: (233, 151) -> 335 (b'\xe9\x97') had 4372 occurrences
# merge 81/5000: (233, 128) -> 336 (b'\xe9\x80') had 4312 occurrences
# merge 82/5000: (233, 157) -> 337 (b'\xe9\x9d') had 4263 occurrences
# merge 83/5000: (229, 185) -> 338 (b'\xe5\xb9') had 4104 occurrences
# merge 84/5000: (326, 128) -> 339 (b'\xe7\x9d\x80') had 4054 occurrences
# merge 85/5000: (229, 175) -> 340 (b'\xe5\xaf') had 4014 occurrences
# merge 86/5000: (290, 180) -> 341 (b'\xe8\xaf\xb4') had 3991 occurrences
# merge 87/5000: (230, 160) -> 342 (b'\xe6\xa0') had 3976 occurrences
# merge 88/5000: (231, 169) -> 343 (b'\xe7\xa9') had 3950 occurrences
# merge 89/5000: (232, 136) -> 344 (b'\xe8\x88') had 3908 occurrences
# merge 90/5000: (232, 296) -> 345 (b'\xe8\x83\xbd') had 3841 occurrences
# merge 91/5000: (231, 155) -> 346 (b'\xe7\x9b') had 3837 occurrences
# merge 92/5000: (232, 167) -> 347 (b'\xe8\xa7') had 3797 occurrences
# merge 93/5000: (301, 139) -> 348 (b'\xe7\x9c\x8b') had 3750 occurrences
# merge 94/5000: (303, 186) -> 349 (b'\xe5\x87\xba') had 3728 occurrences
# merge 95/5000: (261, 230) -> 350 (b'\xe7\x9a\x84\xe6') had 3713 occurrences
# merge 96/5000: (232, 128) -> 351 (b'\xe8\x80') had 3694 occurrences
# merge 97/5000: (233, 152) -> 352 (b'\xe9\x98') had 3629 occurrences
# merge 98/5000: (232, 181) -> 353 (b'\xe8\xb5') had 3572 occurrences
# merge 99/5000: (229, 146) -> 354 (b'\xe5\x92') had 3559 occurrences
# merge 100/5000: (232, 161) -> 355 (b'\xe8\xa1') had 3531 occurrences
# merge 101/5000: (279, 142) -> 356 (b'\xe5\x90\x8e') had 3521 occurrences
# merge 102/5000: (230, 138) -> 357 (b'\xe6\x8a') had 3496 occurrences
# merge 103/5000: (230, 131) -> 358 (b'\xe6\x83') had 3472 occurrences
# merge 104/5000: (231, 167) -> 359 (b'\xe7\xa7') had 3455 occurrences
# merge 105/5000: (274, 160) -> 360 (b'\xe4\xbd\xa0') had 3450 occurrences
# merge 106/5000: (232, 135) -> 361 (b'\xe8\x87') had 3424 occurrences
# merge 107/5000: (229, 142) -> 362 (b'\xe5\x8e') had 3401 occurrences
# merge 108/5000: (286, 177) -> 363 (b'\xe5\xb0\xb1') had 3390 occurrences
# merge 109/5000: (354, 140) -> 364 (b'\xe5\x92\x8c') had 3346 occurrences
# merge 110/5000: (337, 162) -> 365 (b'\xe9\x9d\xa2') had 3343 occurrences
# merge 111/5000: (229, 184) -> 366 (b'\xe5\xb8') had 3323 occurrences
# merge 112/5000: (273, 292) -> 367 (b'\xe4\xb8\x80\xe4\xb8\xaa') had 3249 occurrences
# merge 113/5000: (232, 190) -> 368 (b'\xe8\xbe') had 3229 occurrences
# merge 114/5000: (266, 318) -> 369 (b'\xe3\x80\x82\xe2\x80\x9d\n\xe3\x80\x80\xe3\x80\x80') had 3215 occurrences
# merge 115/5000: (231, 186) -> 370 (b'\xe7\xba') had 3162 occurrences
# merge 116/5000: (320, 176) -> 371 (b'\xe7\x8e\xb0') had 3152 occurrences
# merge 117/5000: (229, 186) -> 372 (b'\xe5\xba') had 3086 occurrences
# merge 118/5000: (233, 296) -> 373 (b'\xe9\x83\xbd') had 3064 occurrences
# merge 119/5000: (230, 173) -> 374 (b'\xe6\xad') had 3054 occurrences
# merge 120/5000: (230, 128) -> 375 (b'\xe6\x80') had 3047 occurrences
# merge 121/5000: (270, 175) -> 376 (b'\xe5\x8f\xaf') had 3000 occurrences
# merge 122/5000: (330, 161) -> 377 (b'\xe6\xb2\xa1') had 2984 occurrences
# merge 123/5000: (269, 170) -> 378 (b'\xe5\xa4\xaa') had 2961 occurrences
# merge 124/5000: (287, 159) -> 379 (b'\xe4\xb9\x9f') had 2922 occurrences
# merge 125/5000: (268, 159) -> 380 (b'\xe6\x98\x9f') had 2893 occurrences
# merge 126/5000: (343, 186) -> 381 (b'\xe7\xa9\xba') had 2891 occurrences
# merge 127/5000: (229, 189) -> 382 (b'\xe5\xbd') had 2849 occurrences
# merge 128/5000: (267, 135) -> 383 (b'\xe8\xbf\x87') had 2815 occurrences
# merge 129/5000: (274, 134) -> 384 (b'\xe4\xbd\x86') had 2795 occurrences
# merge 130/5000: (230, 181) -> 385 (b'\xe6\xb5') had 2781 occurrences
# merge 131/5000: (256, 139) -> 386 (b'\xe4\xb8\x8b') had 2753 occurrences
# merge 132/5000: (257, 159) -> 387 (b'\xef\xbc\x9f') had 2736 occurrences
# merge 133/5000: (229, 137) -> 388 (b'\xe5\x89') had 2733 occurrences
# merge 134/5000: (229, 145) -> 389 (b'\xe5\x91') had 2727 occurrences
# merge 135/5000: (233, 129) -> 390 (b'\xe9\x81') had 2722 occurrences
# merge 136/5000: (270, 145) -> 391 (b'\xe5\x8f\x91') had 2658 occurrences
# merge 137/5000: (231, 144) -> 392 (b'\xe7\x90') had 2657 occurrences
# merge 138/5000: (340, 185) -> 393 (b'\xe5\xaf\xb9') had 2655 occurrences
# merge 139/5000: (256, 186) -> 394 (b'\xe4\xb8\xba') had 2642 occurrences
# merge 140/5000: (309, 144) -> 395 (b'\xe5\xad\x90') had 2636 occurrences
# merge 141/5000: (332, 131) -> 396 (b'\xe5\xbf\x83') had 2629 occurrences
# merge 142/5000: (230, 142) -> 397 (b'\xe6\x8e') had 2613 occurrences
# merge 143/5000: (264, 165) -> 398 (b'\xe4\xbb\xa5') had 2555 occurrences
# merge 144/5000: (257, 154) -> 399 (b'\xef\xbc\x9a') had 2527 occurrences
# merge 145/5000: (230, 158) -> 400 (b'\xe6\x9e') had 2524 occurrences
# merge 146/5000: (231, 168) -> 401 (b'\xe7\xa8') had 2522 occurrences
# merge 147/5000: (287, 136) -> 402 (b'\xe4\xb9\x88') had 2479 occurrences
# merge 148/5000: (256, 137) -> 403 (b'\xe4\xb8\x89') had 2438 occurrences
# merge 149/5000: (232, 189) -> 404 (b'\xe8\xbd') had 2430 occurrences
# merge 150/5000: (231, 137) -> 405 (b'\xe7\x89') had 2406 occurrences
# merge 151/5000: (230, 149) -> 406 (b'\xe6\x95') had 2401 occurrences
# merge 152/5000: (232, 166) -> 407 (b'\xe8\xa6') had 2400 occurrences
# merge 153/5000: (274, 147) -> 408 (b'\xe4\xbd\x93') had 2393 occurrences
# merge 154/5000: (361, 170) -> 409 (b'\xe8\x87\xaa') had 2375 occurrences
# merge 155/5000: (270, 170) -> 410 (b'\xe5\x8f\xaa') had 2373 occurrences
# merge 156/5000: (231, 132) -> 411 (b'\xe7\x84') had 2365 occurrences
# merge 157/5000: (229, 163) -> 412 (b'\xe5\xa3') had 2357 occurrences
# merge 158/5000: (407, 129) -> 413 (b'\xe8\xa6\x81') had 2334 occurrences
# merge 159/5000: (230, 132) -> 414 (b'\xe6\x84') had 2328 occurrences
# merge 160/5000: (258, 285) -> 415 (b'\xef\xbc\x8c\xe8\xbf\x99') had 2323 occurrences
# merge 161/5000: (305, 136) -> 416 (b'\xe5\xbe\x88') had 2275 occurrences
# merge 162/5000: (328, 154) -> 417 (b'\xe4\xbc\x9a') had 2274 occurrences
# merge 163/5000: (231, 189) -> 418 (b'\xe7\xbd') had 2267 occurrences
# merge 164/5000: (355, 140) -> 419 (b'\xe8\xa1\x8c') had 2253 occurrences
# merge 165/5000: (231, 159) -> 420 (b'\xe7\x9f') had 2252 occurrences
# merge 166/5000: (283, 137) -> 421 (b'\xe5\x85\x89') had 2225 occurrences
# merge 167/5000: (304, 288) -> 422 (b'\xe3\x80\x82\n\xe3\x80\x80\xe3\x80\x80\xe2\x80\x9c') had 2222 occurrences
# merge 168/5000: (411, 182) -> 423 (b'\xe7\x84\xb6') had 2199 occurrences
# merge 169/5000: (401, 139) -> 424 (b'\xe7\xa8\x8b') had 2186 occurrences
# merge 170/5000: (284, 144) -> 425 (b'\xe6\x88\x90') had 2178 occurrences
# merge 171/5000: (335, 180) -> 426 (b'\xe9\x97\xb4') had 2163 occurrences
# merge 172/5000: (377, 291) -> 427 (b'\xe6\xb2\xa1\xe6\x9c\x89') had 2156 occurrences
# merge 173/5000: (231, 149) -> 428 (b'\xe7\x95') had 2152 occurrences
# merge 174/5000: (298, 159) -> 429 (b'\xe7\x94\x9f') had 2150 occurrences
# merge 175/5000: (269, 169) -> 430 (b'\xe5\xa4\xa9') had 2141 occurrences
# merge 176/5000: (230, 175) -> 431 (b'\xe6\xaf') had 2110 occurrences
# merge 177/5000: (358, 179) -> 432 (b'\xe6\x83\xb3') had 2098 occurrences
# merge 178/5000: (388, 141) -> 433 (b'\xe5\x89\x8d') had 2096 occurrences
# merge 179/5000: (324, 140) -> 434 (b'\xe9\x87\x8c') had 2087 occurrences
# merge 180/5000: (233, 153) -> 435 (b'\xe9\x99') had 2086 occurrences
# merge 181/5000: (230, 180) -> 436 (b'\xe6\xb4') had 2075 occurrences
# merge 182/5000: (131, 143) -> 437 (b'\x83\x8f') had 2073 occurrences
# merge 183/5000: (258, 384) -> 438 (b'\xef\xbc\x8c\xe4\xbd\x86') had 2072 occurrences
# merge 184/5000: (230, 139) -> 439 (b'\xe6\x8b') had 2061 occurrences
# merge 185/5000: (333, 185) -> 440 (b'\xe5\xa5\xb9') had 2040 occurrences
# merge 186/5000: (230, 176) -> 441 (b'\xe6\xb0') had 2036 occurrences
# merge 187/5000: (390, 147) -> 442 (b'\xe9\x81\x93') had 2024 occurrences
# merge 188/5000: (265, 166) -> 443 (b'\xe2\x80\xa6') had 2006 occurrences
# merge 189/5000: (229, 177) -> 444 (b'\xe5\xb1') had 1990 occurrences
# merge 190/5000: (233, 149) -> 445 (b'\xe9\x95') had 1986 occurrences
# merge 191/5000: (258, 302) -> 446 (b'\xef\xbc\x8c\xe4\xbb\x96') had 1980 occurrences
# merge 192/5000: (342, 183) -> 447 (b'\xe6\xa0\xb7') had 1979 occurrences
# merge 193/5000: (307, 135) -> 448 (b'\xe6\x96\x87') had 1977 occurrences
# merge 194/5000: (231, 171) -> 449 (b'\xe7\xab') had 1971 occurrences
# merge 195/5000: (353, 183) -> 450 (b'\xe8\xb5\xb7') had 1960 occurrences
# merge 196/5000: (230, 179) -> 451 (b'\xe6\xb3') had 1959 occurrences
# merge 197/5000: (233, 163) -> 452 (b'\xe9\xa3') had 1953 occurrences
# merge 198/5000: (362, 187) -> 453 (b'\xe5\x8e\xbb') had 1951 occurrences
# merge 199/5000: (256, 150) -> 454 (b'\xe4\xb8\x96') had 1937 occurrences
# merge 200/5000: (230, 140) -> 455 (b'\xe6\x8c') had 1927 occurrences
# merge 201/5000: (268, 142) -> 456 (b'\xe6\x98\x8e') had 1918 occurrences
# merge 202/5000: (262, 142) -> 457 (b'\xe4\xba\x8e') had 1910 occurrences
# merge 203/5000: (369, 288) -> 458 (b'\xe3\x80\x82\xe2\x80\x9d\n\xe3\x80\x80\xe3\x80\x80\xe2\x80\x9c') had 1903 occurrences
# merge 204/5000: (286, 143) -> 459 (b'\xe5\xb0\x8f') had 1879 occurrences
# merge 205/5000: (282, 131) -> 460 (b'\xe5\xae\x83') had 1866 occurrences
# merge 206/5000: (232, 137) -> 461 (b'\xe8\x89') had 1858 occurrences
# merge 207/5000: (228, 191) -> 462 (b'\xe4\xbf') had 1853 occurrences
# merge 208/5000: (230, 148) -> 463 (b'\xe6\x94') had 1842 occurrences
# merge 209/5000: (272, 128) -> 464 (b'\xe6\x9c\x80') had 1841 occurrences
# merge 210/5000: (267, 152) -> 465 (b'\xe8\xbf\x98') had 1828 occurrences
# merge 211/5000: (230, 129) -> 466 (b'\xe6\x81') had 1826 occurrences
# merge 212/5000: (269, 154) -> 467 (b'\xe5\xa4\x9a') had 1825 occurrences
# merge 213/5000: (261, 231) -> 468 (b'\xe7\x9a\x84\xe7') had 1811 occurrences
# merge 214/5000: (264, 142) -> 469 (b'\xe4\xbb\x8e') had 1805 occurrences
# merge 215/5000: (293, 143) -> 470 (b'\xe7\xbb\x8f') had 1797 occurrences
# merge 216/5000: (229, 140) -> 471 (b'\xe5\x8c') had 1794 occurrences
# merge 217/5000: (233, 162) -> 472 (b'\xe9\xa2') had 1793 occurrences
# merge 218/5000: (230, 172) -> 473 (b'\xe6\xac') had 1791 occurrences
# merge 219/5000: (305, 151) -> 474 (b'\xe5\xbe\x97') had 1770 occurrences
# merge 220/5000: (267, 155) -> 475 (b'\xe8\xbf\x9b') had 1741 occurrences
# merge 221/5000: (279, 145) -> 476 (b'\xe5\x90\x91') had 1735 occurrences
# merge 222/5000: (231, 177) -> 477 (b'\xe7\xb1') had 1728 occurrences
# merge 223/5000: (307, 185) -> 478 (b'\xe6\x96\xb9') had 1719 occurrences
# merge 224/5000: (315, 168) -> 479 (b'\xe5\x8a\xa8') had 1718 occurrences
# merge 225/5000: (262, 155) -> 480 (b'\xe4\xba\x9b') had 1714 occurrences
# merge 226/5000: (316, 178) -> 481 (b'\xe5\xb7\xb2') had 1695 occurrences
# merge 227/5000: (359, 141) -> 482 (b'\xe7\xa7\x8d') had 1660 occurrences
# merge 228/5000: (261, 232) -> 483 (b'\xe7\x9a\x84\xe8') had 1650 occurrences
# merge 229/5000: (231, 130) -> 484 (b'\xe7\x82') had 1648 occurrences
# merge 230/5000: (258, 313) -> 485 (b'\xef\xbc\x8c\xe6\x88\x91') had 1646 occurrences
# merge 231/5000: (317, 128) -> 486 (b'\xe5\xbc\x80') had 1643 occurrences
# merge 232/5000: (256, 164) -> 487 (b'\xe4\xb8\xa4') had 1625 occurrences
# merge 233/5000: (232, 162) -> 488 (b'\xe8\xa2') had 1608 occurrences
# merge 234/5000: (315, 155) -> 489 (b'\xe5\x8a\x9b') had 1599 occurrences
# merge 235/5000: (428, 140) -> 490 (b'\xe7\x95\x8c') had 1589 occurrences
# merge 236/5000: (275, 134) -> 491 (b'\xe5\x88\x86') had 1588 occurrences
# merge 237/5000: (231, 179) -> 492 (b'\xe7\xb3') had 1583 occurrences
# merge 238/5000: (230, 153) -> 493 (b'\xe6\x99') had 1580 occurrences
# merge 239/5000: (229, 437) -> 494 (b'\xe5\x83\x8f') had 1580 occurrences
# merge 240/5000: (357, 138) -> 495 (b'\xe6\x8a\x8a') had 1574 occurrences
# merge 241/5000: (445, 191) -> 496 (b'\xe9\x95\xbf') had 1554 occurrences
# merge 242/5000: (264, 128) -> 497 (b'\xe4\xbb\x80') had 1529 occurrences
# merge 243/5000: (424, 396) -> 498 (b'\xe7\xa8\x8b\xe5\xbf\x83') had 1529 occurrences
# merge 244/5000: (497, 402) -> 499 (b'\xe4\xbb\x80\xe4\xb9\x88') had 1526 occurrences
# merge 245/5000: (352, 179) -> 500 (b'\xe9\x98\xb3') had 1521 occurrences
# merge 246/5000: (298, 168) -> 501 (b'\xe7\x94\xa8') had 1520 occurrences
# merge 247/5000: (229, 157) -> 502 (b'\xe5\x9d') had 1519 occurrences
# merge 248/5000: (229, 159) -> 503 (b'\xe5\x9f') had 1517 occurrences
# merge 249/5000: (310, 128) -> 504 (b'\xe6\x89\x80') had 1513 occurrences
# merge 250/5000: (392, 131) -> 505 (b'\xe7\x90\x83') had 1510 occurrences
# merge 251/5000: (230, 183) -> 506 (b'\xe6\xb7') had 1497 occurrences
# merge 252/5000: (233, 187) -> 507 (b'\xe9\xbb') had 1494 occurrences
# merge 253/5000: (256, 142) -> 508 (b'\xe4\xb8\x8e') had 1493 occurrences
# merge 254/5000: (230, 155) -> 509 (b'\xe6\x9b') had 1489 occurrences
# merge 255/5000: (420, 165) -> 510 (b'\xe7\x9f\xa5') had 1488 occurrences
# merge 256/5000: (262, 139) -> 511 (b'\xe4\xba\x8b') had 1472 occurrences
# merge 257/5000: (233, 131) -> 512 (b'\xe9\x83') had 1471 occurrences
# merge 258/5000: (492, 187) -> 513 (b'\xe7\xb3\xbb') had 1465 occurrences
# merge 259/5000: (418, 151) -> 514 (b'\xe7\xbd\x97') had 1460 occurrences
# merge 260/5000: (488, 171) -> 515 (b'\xe8\xa2\xab') had 1458 occurrences
# merge 261/5000: (233, 155) -> 516 (b'\xe9\x9b') had 1446 occurrences
# merge 262/5000: (233, 154) -> 517 (b'\xe9\x9a') had 1442 occurrences
# merge 263/5000: (314, 129) -> 518 (b'\xe5\x8d\x81') had 1442 occurrences
# merge 264/5000: (279, 140) -> 519 (b'\xe5\x90\x8c') had 1439 occurrences
# merge 265/5000: (266, 289) -> 520 (b'\xe3\x80\x82\xe2\x80\x9d') had 1438 occurrences
# merge 266/5000: (231, 172) -> 521 (b'\xe7\xac') had 1433 occurrences
# merge 267/5000: (473, 161) -> 522 (b'\xe6\xac\xa1') had 1432 occurrences
# merge 268/5000: (316, 177) -> 523 (b'\xe5\xb7\xb1') had 1409 occurrences
# merge 269/5000: (230, 184) -> 524 (b'\xe6\xb8') had 1400 occurrences
# merge 270/5000: (231, 153) -> 525 (b'\xe7\x99') had 1399 occurrences
# merge 271/5000: (409, 523) -> 526 (b'\xe8\x87\xaa\xe5\xb7\xb1') had 1395 occurrences
# merge 272/5000: (512, 168) -> 527 (b'\xe9\x83\xa8') had 1394 occurrences
# merge 273/5000: (452, 158) -> 528 (b'\xe9\xa3\x9e') had 1378 occurrences
# merge 274/5000: (231, 129) -> 529 (b'\xe7\x81') had 1372 occurrences
# merge 275/5000: (270, 183) -> 530 (b'\xe5\x8f\xb7') had 1368 occurrences
# merge 276/5000: (338, 180) -> 531 (b'\xe5\xb9\xb4') had 1367 occurrences
# merge 277/5000: (454, 490) -> 532 (b'\xe4\xb8\x96\xe7\x95\x8c') had 1366 occurrences
# merge 278/5000: (344, 176) -> 533 (b'\xe8\x88\xb0') had 1365 occurrences
# merge 279/5000: (229, 129) -> 534 (b'\xe5\x81') had 1365 occurrences
# merge 280/5000: (351, 133) -> 535 (b'\xe8\x80\x85') had 1361 occurrences
# merge 281/5000: (272, 186) -> 536 (b'\xe6\x9c\xba') had 1347 occurrences
# merge 282/5000: (287, 139) -> 537 (b'\xe4\xb9\x8b') had 1342 occurrences
# merge 283/5000: (282, 158) -> 538 (b'\xe5\xae\x9e') had 1342 occurrences
# merge 284/5000: (371, 280) -> 539 (b'\xe7\x8e\xb0\xe5\x9c\xa8') had 1337 occurrences
# merge 285/5000: (258, 280) -> 540 (b'\xef\xbc\x8c\xe5\x9c\xa8') had 1324 occurrences
# merge 286/5000: (484, 185) -> 541 (b'\xe7\x82\xb9') had 1324 occurrences
# merge 287/5000: (368, 145) -> 542 (b'\xe8\xbe\x91') had 1319 occurrences
# merge 288/5000: (257, 129) -> 543 (b'\xef\xbc\x81') had 1319 occurrences
# merge 289/5000: (336, 159) -> 544 (b'\xe9\x80\x9f') had 1309 occurrences
# merge 290/5000: (295, 160) -> 545 (b'\xe6\x97\xa0') had 1298 occurrences
# merge 291/5000: (514, 542) -> 546 (b'\xe7\xbd\x97\xe8\xbe\x91') had 1294 occurrences
# merge 292/5000: (378, 381) -> 547 (b'\xe5\xa4\xaa\xe7\xa9\xba') had 1292 occurrences
# merge 293/5000: (232, 180) -> 548 (b'\xe8\xb4') had 1290 occurrences
# merge 294/5000: (269, 150) -> 549 (b'\xe5\xa4\x96') had 1289 occurrences
# merge 295/5000: (166, 130) -> 550 (b'\xa6\x82') had 1282 occurrences
# merge 296/5000: (293, 180) -> 551 (b'\xe7\xbb\xb4') had 1282 occurrences
# merge 297/5000: (269, 180) -> 552 (b'\xe5\xa4\xb4') had 1279 occurrences
# merge 298/5000: (351, 140) -> 553 (b'\xe8\x80\x8c') had 1271 occurrences
# merge 299/5000: (378, 500) -> 554 (b'\xe5\xa4\xaa\xe9\x98\xb3') had 1264 occurrences
# merge 300/5000: (376, 345) -> 555 (b'\xe5\x8f\xaf\xe8\x83\xbd') had 1260 occurrences
# merge 301/5000: (283, 182) -> 556 (b'\xe5\x85\xb6') had 1253 occurrences
# merge 302/5000: (232, 183) -> 557 (b'\xe8\xb7') had 1252 occurrences
# merge 303/5000: (477, 187) -> 558 (b'\xe7\xb1\xbb') had 1250 occurrences
# merge 304/5000: (309, 166) -> 559 (b'\xe5\xad\xa6') had 1229 occurrences
# merge 305/5000: (462, 161) -> 560 (b'\xe4\xbf\xa1') had 1218 occurrences
# merge 306/5000: (481, 470) -> 561 (b'\xe5\xb7\xb2\xe7\xbb\x8f') had 1206 occurrences
# merge 307/5000: (283, 168) -> 562 (b'\xe5\x85\xa8') had 1197 occurrences
# merge 308/5000: (274, 191) -> 563 (b'\xe4\xbd\xbf') had 1184 occurrences
# merge 309/5000: (230, 130) -> 564 (b'\xe6\x82') had 1183 occurrences
# merge 310/5000: (281, 258) -> 565 (b'\xe4\xba\x86\xef\xbc\x8c') had 1176 occurrences
# merge 311/5000: (333, 189) -> 566 (b'\xe5\xa5\xbd') had 1175 occurrences
# merge 312/5000: (335, 174) -> 567 (b'\xe9\x97\xae') had 1164 occurrences
# merge 313/5000: (414, 143) -> 568 (b'\xe6\x84\x8f') had 1153 occurrences
# merge 314/5000: (258, 288) -> 569 (b'\xef\xbc\x8c\xe2\x80\x9c') had 1145 occurrences
# merge 315/5000: (230, 177) -> 570 (b'\xe6\xb1') had 1142 occurrences
# merge 316/5000: (231, 174) -> 571 (b'\xe7\xae') had 1141 occurrences
# merge 317/5000: (301, 159) -> 572 (b'\xe7\x9c\x9f') had 1137 occurrences
# merge 318/5000: (270, 152) -> 573 (b'\xe5\x8f\x98') had 1135 occurrences
# merge 319/5000: (318, 288) -> 574 (b'\xe2\x80\x9d\n\xe3\x80\x80\xe3\x80\x80\xe2\x80\x9c') had 1131 occurrences
# merge 320/5000: (232, 186) -> 575 (b'\xe8\xba') had 1128 occurrences
# merge 321/5000: (282, 154) -> 576 (b'\xe5\xae\x9a') had 1128 occurrences
# merge 322/5000: (302, 312) -> 577 (b'\xe4\xbb\x96\xe4\xbb\xac') had 1122 occurrences
# merge 323/5000: (348, 306) -> 578 (b'\xe7\x9c\x8b\xe5\x88\xb0') had 1122 occurrences
# merge 324/5000: (285, 292) -> 579 (b'\xe8\xbf\x99\xe4\xb8\xaa') had 1118 occurrences
# merge 325/5000: (232, 182) -> 580 (b'\xe8\xb6') had 1111 occurrences
# merge 326/5000: (510, 442) -> 581 (b'\xe7\x9f\xa5\xe9\x81\x93') had 1108 occurrences
# merge 327/5000: (232, 176) -> 582 (b'\xe8\xb0') had 1107 occurrences
# merge 328/5000: (346, 174) -> 583 (b'\xe7\x9b\xae') had 1094 occurrences
# merge 329/5000: (372, 166) -> 584 (b'\xe5\xba\xa6') had 1086 occurrences
# merge 330/5000: (256, 187) -> 585 (b'\xe4\xb8\xbb') had 1070 occurrences
# merge 331/5000: (274, 156) -> 586 (b'\xe4\xbd\x9c') had 1067 occurrences
# merge 332/5000: (392, 134) -> 587 (b'\xe7\x90\x86') had 1066 occurrences
# merge 333/5000: (229, 147) -> 588 (b'\xe5\x93') had 1065 occurrences
# merge 334/5000: (461, 178) -> 589 (b'\xe8\x89\xb2') had 1061 occurrences
# merge 335/5000: (300, 165) -> 590 (b'\xef\xbc\x8c\xe5\xa5') had 1060 occurrences
# merge 336/5000: (352, 159) -> 591 (b'\xe9\x98\x9f') had 1060 occurrences
# merge 337/5000: (229, 167) -> 592 (b'\xe5\xa7') had 1058 occurrences
# merge 338/5000: (299, 558) -> 593 (b'\xe4\xba\xba\xe7\xb1\xbb') had 1051 occurrences
# merge 339/5000: (374, 163) -> 594 (b'\xe6\xad\xa3') had 1051 occurrences
# merge 340/5000: (301, 188) -> 595 (b'\xe7\x9c\xbc') had 1050 occurrences
# merge 341/5000: (290, 157) -> 596 (b'\xe8\xaf\x9d') had 1049 occurrences
# merge 342/5000: (399, 288) -> 597 (b'\xef\xbc\x9a\xe2\x80\x9c') had 1049 occurrences
# merge 343/5000: (261, 258) -> 598 (b'\xe7\x9a\x84\xef\xbc\x8c') had 1045 occurrences
# merge 344/5000: (303, 160) -> 599 (b'\xe5\x87\xa0') had 1039 occurrences
# merge 345/5000: (267, 156) -> 600 (b'\xe8\xbf\x9c') had 1036 occurrences
# merge 346/5000: (319, 189) -> 601 (b'\xe5\x9b\xbd') had 1034 occurrences
# merge 347/5000: (313, 312) -> 602 (b'\xe6\x88\x91\xe4\xbb\xac') had 1033 occurrences
# merge 348/5000: (403, 408) -> 603 (b'\xe4\xb8\x89\xe4\xbd\x93') had 1031 occurrences
# merge 349/5000: (231, 173) -> 604 (b'\xe7\xad') had 1029 occurrences
# merge 350/5000: (262, 140) -> 605 (b'\xe4\xba\x8c') had 1026 occurrences
# merge 351/5000: (346, 184) -> 606 (b'\xe7\x9b\xb8') had 1020 occurrences
# merge 352/5000: (319, 158) -> 607 (b'\xe5\x9b\x9e') had 1004 occurrences
# merge 353/5000: (443, 443) -> 608 (b'\xe2\x80\xa6\xe2\x80\xa6') had 1003 occurrences
# merge 354/5000: (414, 159) -> 609 (b'\xe6\x84\x9f') had 1003 occurrences
# merge 355/5000: (281, 273) -> 610 (b'\xe4\xba\x86\xe4\xb8\x80') had 997 occurrences
# merge 356/5000: (282, 135) -> 611 (b'\xe5\xae\x87') had 996 occurrences
# merge 357/5000: (353, 176) -> 612 (b'\xe8\xb5\xb0') had 996 occurrences
# merge 358/5000: (412, 176) -> 613 (b'\xe5\xa3\xb0') had 978 occurrences
# merge 359/5000: (261, 273) -> 614 (b'\xe7\x9a\x84\xe4\xb8\x80') had 978 occurrences
# merge 360/5000: (310, 139) -> 615 (b'\xe6\x89\x8b') had 974 occurrences
# merge 361/5000: (385, 183) -> 616 (b'\xe6\xb5\xb7') had 972 occurrences
# merge 362/5000: (321, 505) -> 617 (b'\xe5\x9c\xb0\xe7\x90\x83') had 971 occurrences
# merge 363/5000: (286, 134) -> 618 (b'\xe5\xb0\x86') had 971 occurrences
# merge 364/5000: (233, 156) -> 619 (b'\xe9\x9c') had 970 occurrences
# merge 365/5000: (282, 153) -> 620 (b'\xe5\xae\x99') had 967 occurrences
# merge 366/5000: (611, 620) -> 621 (b'\xe5\xae\x87\xe5\xae\x99') had 966 occurrences
# merge 367/5000: (397, 165) -> 622 (b'\xe6\x8e\xa5') had 966 occurrences
# merge 368/5000: (229, 128) -> 623 (b'\xe5\x80') had 963 occurrences
# merge 369/5000: (382, 147) -> 624 (b'\xe5\xbd\x93') had 961 occurrences
# merge 370/5000: (284, 152) -> 625 (b'\xe6\x88\x98') had 958 occurrences
# merge 371/5000: (261, 299) -> 626 (b'\xe7\x9a\x84\xe4\xba\xba') had 949 occurrences
# merge 372/5000: (325, 161) -> 627 (b'\xe8\xae\xa1') had 946 occurrences
# merge 373/5000: (283, 165) -> 628 (b'\xe5\x85\xa5') had 942 occurrences
# merge 374/5000: (231, 164) -> 629 (b'\xe7\xa4') had 942 occurrences
# merge 375/5000: (575, 171) -> 630 (b'\xe8\xba\xab') had 939 occurrences
# merge 376/5000: (344, 185) -> 631 (b'\xe8\x88\xb9') had 935 occurrences
# merge 377/5000: (324, 141) -> 632 (b'\xe9\x87\x8d') had 934 occurrences
# merge 378/5000: (258, 331) -> 633 (b'\xef\xbc\x8c\xe9\x82\xa3') had 931 occurrences
# merge 379/5000: (274, 141) -> 634 (b'\xe4\xbd\x8d') had 930 occurrences
# merge 380/5000: (270, 136) -> 635 (b'\xe5\x8f\x88') had 926 occurrences
# merge 381/5000: (400, 156) -> 636 (b'\xe6\x9e\x9c') had 923 occurrences
# merge 382/5000: (229, 187) -> 637 (b'\xe5\xbb') had 921 occurrences
# merge 383/5000: (233, 171) -> 638 (b'\xe9\xab') had 918 occurrences
# merge 384/5000: (230, 187) -> 639 (b'\xe6\xbb') had 915 occurrences
# merge 385/5000: (363, 276) -> 640 (b'\xe5\xb0\xb1\xe6\x98\xaf') had 911 occurrences
# merge 386/5000: (638, 152) -> 641 (b'\xe9\xab\x98') had 909 occurrences
# merge 387/5000: (324, 143) -> 642 (b'\xe9\x87\x8f') had 908 occurrences
# merge 388/5000: (269, 132) -> 643 (b'\xe5\xa4\x84') had 905 occurrences
# merge 389/5000: (590, 185) -> 644 (b'\xef\xbc\x8c\xe5\xa5\xb9') had 903 occurrences
# merge 390/5000: (231, 166) -> 645 (b'\xe7\xa6') had 898 occurrences
# merge 391/5000: (346, 180) -> 646 (b'\xe7\x9b\xb4') had 897 occurrences
# merge 392/5000: (507, 145) -> 647 (b'\xe9\xbb\x91') had 889 occurrences
# merge 393/5000: (405, 169) -> 648 (b'\xe7\x89\xa9') had 880 occurrences
# merge 394/5000: (230, 182) -> 649 (b'\xe6\xb6') had 878 occurrences
# merge 395/5000: (441, 180) -> 650 (b'\xe6\xb0\xb4') had 878 occurrences
# merge 396/5000: (264, 163) -> 651 (b'\xe4\xbb\xa3') had 870 occurrences
# merge 397/5000: (376, 398) -> 652 (b'\xe5\x8f\xaf\xe4\xbb\xa5') had 867 occurrences
# merge 398/5000: (259, 129) -> 653 (b'\xe3\x80\x81') had 865 occurrences
# merge 399/5000: (231, 131) -> 654 (b'\xe7\x83') had 861 occurrences
# merge 400/5000: (382, 162) -> 655 (b'\xe5\xbd\xa2') had 856 occurrences
# merge 401/5000: (323, 426) -> 656 (b'\xe6\x97\xb6\xe9\x97\xb4') had 856 occurrences
# merge 402/5000: (294, 276) -> 657 (b'\xe4\xb8\x8d\xe6\x98\xaf') had 842 occurrences
# merge 403/5000: (283, 179) -> 658 (b'\xe5\x85\xb3') had 841 occurrences
# merge 404/5000: (232, 132) -> 659 (b'\xe8\x84') had 838 occurrences
# merge 405/5000: (230, 145) -> 660 (b'\xe6\x91') had 837 occurrences
# merge 406/5000: (270, 178) -> 661 (b'\xe5\x8f\xb2') had 836 occurrences
# merge 407/5000: (229, 550) -> 662 (b'\xe5\xa6\x82') had 835 occurrences
# merge 408/5000: (283, 172) -> 663 (b'\xe5\x85\xac') had 835 occurrences
# merge 409/5000: (233, 161) -> 664 (b'\xe9\xa1') had 834 occurrences
# merge 410/5000: (279, 151) -> 665 (b'\xe5\x90\x97') had 833 occurrences
# merge 411/5000: (231, 190) -> 666 (b'\xe7\xbe') had 829 occurrences
# merge 412/5000: (282, 140) -> 667 (b'\xe5\xae\x8c') had 829 occurrences
# merge 413/5000: (132, 191) -> 668 (b'\x84\xbf') had 821 occurrences
# merge 414/5000: (269, 177) -> 669 (b'\xe5\xa4\xb1') had 818 occurrences
# merge 415/5000: (286, 132) -> 670 (b'\xe5\xb0\x84') had 817 occurrences
# merge 416/5000: (347, 137) -> 671 (b'\xe8\xa7\x89') had 817 occurrences
# merge 417/5000: (387, 574) -> 672 (b'\xef\xbc\x9f\xe2\x80\x9d\n\xe3\x80\x80\xe3\x80\x80\xe2\x80\x9c') had 809 occurrences
# merge 418/5000: (534, 154) -> 673 (b'\xe5\x81\x9a') had 805 occurrences
# merge 419/5000: (165, 191) -> 674 (b'\xa5\xbf') had 802 occurrences
# merge 420/5000: (232, 129) -> 675 (b'\xe8\x81') had 802 occurrences
# merge 421/5000: (431, 148) -> 676 (b'\xe6\xaf\x94') had 800 occurrences
# merge 422/5000: (229, 153) -> 677 (b'\xe5\x99') had 794 occurrences
# merge 423/5000: (229, 668) -> 678 (b'\xe5\x84\xbf') had 794 occurrences
# merge 424/5000: (231, 160) -> 679 (b'\xe7\xa0') had 791 occurrences
# merge 425/5000: (298, 177) -> 680 (b'\xe7\x94\xb1') had 791 occurrences
# merge 426/5000: (282, 182) -> 681 (b'\xe5\xae\xb6') had 791 occurrences
# merge 427/5000: (334, 155) -> 682 (b'\xe5\x86\x9b') had 789 occurrences
# merge 428/5000: (298, 181) -> 683 (b'\xe7\x94\xb5') had 789 occurrences
# merge 429/5000: (332, 171) -> 684 (b'\xe5\xbf\xab') had 788 occurrences
# merge 430/5000: (230, 154) -> 685 (b'\xe6\x9a') had 787 occurrences
# merge 431/5000: (231, 161) -> 686 (b'\xe7\xa1') had 786 occurrences
# merge 432/5000: (231, 188) -> 687 (b'\xe7\xbc') had 785 occurrences
# merge 433/5000: (325, 169) -> 688 (b'\xe8\xae\xa9') had 778 occurrences
# merge 434/5000: (509, 180) -> 689 (b'\xe6\x9b\xb4') had 770 occurrences
# merge 435/5000: (232, 674) -> 690 (b'\xe8\xa5\xbf') had 767 occurrences
# merge 436/5000: (334, 133) -> 691 (b'\xe5\x86\x85') had 766 occurrences
# merge 437/5000: (233, 146) -> 692 (b'\xe9\x92') had 766 occurrences
# merge 438/5000: (466, 175) -> 693 (b'\xe6\x81\xaf') had 765 occurrences
# merge 439/5000: (231, 170) -> 694 (b'\xe7\xaa') had 758 occurrences
# merge 440/5000: (230, 143) -> 695 (b'\xe6\x8f') had 758 occurrences
# merge 441/5000: (268, 190) -> 696 (b'\xe6\x98\xbe') had 756 occurrences
# merge 442/5000: (319, 155) -> 697 (b'\xe5\x9b\x9b') had 755 occurrences
# merge 443/5000: (645, 187) -> 698 (b'\xe7\xa6\xbb') had 755 occurrences
# merge 444/5000: (229, 162) -> 699 (b'\xe5\xa2') had 752 occurrences
# merge 445/5000: (279, 167) -> 700 (b'\xe5\x90\xa7') had 751 occurrences
# merge 446/5000: (272, 172) -> 701 (b'\xe6\x9c\xac') had 749 occurrences
# merge 447/5000: (405, 135) -> 702 (b'\xe7\x89\x87') had 742 occurrences
# merge 448/5000: (256, 156) -> 703 (b'\xe4\xb8\x9c') had 741 occurrences
# merge 449/5000: (264, 187) -> 704 (b'\xe4\xbb\xbb') had 737 occurrences
# merge 450/5000: (525, 189) -> 705 (b'\xe7\x99\xbd') had 737 occurrences
# merge 451/5000: (370, 170) -> 706 (b'\xe7\xba\xaa') had 734 occurrences
# merge 452/5000: (521, 172) -> 707 (b'\xe7\xac\xac') had 733 occurrences
# merge 453/5000: (338, 179) -> 708 (b'\xe5\xb9\xb3') had 733 occurrences
# merge 454/5000: (289, 530) -> 709 (b'\xe2\x80\x9d\xe5\x8f\xb7') had 731 occurrences
# merge 455/5000: (355, 168) -> 710 (b'\xe8\xa1\xa8') had 729 occurrences
# merge 456/5000: (310, 141) -> 711 (b'\xe6\x89\x8d') had 729 occurrences
# merge 457/5000: (412, 129) -> 712 (b'\xe5\xa3\x81') had 727 occurrences
# merge 458/5000: (677, 168) -> 713 (b'\xe5\x99\xa8') had 727 occurrences
# merge 459/5000: (308, 261) -> 714 (b'\xe4\xb8\xad\xe7\x9a\x84') had 727 occurrences
# merge 460/5000: (451, 149) -> 715 (b'\xe6\xb3\x95') had 726 occurrences
# merge 461/5000: (334, 141) -> 716 (b'\xe5\x86\x8d') had 726 occurrences
# merge 462/5000: (323, 258) -> 717 (b'\xe6\x97\xb6\xef\xbc\x8c') had 723 occurrences
# merge 463/5000: (309, 152) -> 718 (b'\xe5\xad\x98') had 720 occurrences
# merge 464/5000: (564, 168) -> 719 (b'\xe6\x82\xa8') had 718 occurrences
# merge 465/5000: (308, 258) -> 720 (b'\xe4\xb8\xad\xef\xbc\x8c') had 717 occurrences
# merge 466/5000: (316, 165) -> 721 (b'\xe5\xb7\xa5') had 711 occurrences
# merge 467/5000: (231, 136) -> 722 (b'\xe7\x88') had 706 occurrences
# merge 468/5000: (315, 160) -> 723 (b'\xe5\x8a\xa0') had 706 occurrences
# merge 469/5000: (229, 178) -> 724 (b'\xe5\xb2') had 702 occurrences
# merge 470/5000: (592, 139) -> 725 (b'\xe5\xa7\x8b') had 699 occurrences
# merge 471/5000: (228, 190) -> 726 (b'\xe4\xbe') had 690 occurrences
# merge 472/5000: (258, 360) -> 727 (b'\xef\xbc\x8c\xe4\xbd\xa0') had 689 occurrences
# merge 473/5000: (232, 130) -> 728 (b'\xe8\x82') had 687 occurrences
# merge 474/5000: (258, 410) -> 729 (b'\xef\xbc\x8c\xe5\x8f\xaa') had 683 occurrences
# merge 475/5000: (455, 135) -> 730 (b'\xe6\x8c\x87') had 683 occurrences
# merge 476/5000: (256, 135) -> 731 (b'\xe4\xb8\x87') had 679 occurrences
# merge 477/5000: (361, 179) -> 732 (b'\xe8\x87\xb3') had 678 occurrences
# merge 478/5000: (385, 139) -> 733 (b'\xe6\xb5\x8b') had 672 occurrences
# merge 479/5000: (285, 447) -> 734 (b'\xe8\xbf\x99\xe6\xa0\xb7') had 672 occurrences
# merge 480/5000: (231, 178) -> 735 (b'\xe7\xb2') had 670 occurrences
# merge 481/5000: (570, 170) -> 736 (b'\xe6\xb1\xaa') had 667 occurrences
# merge 482/5000: (275, 171) -> 737 (b'\xe5\x88\xab') had 666 occurrences
# merge 483/5000: (372, 148) -> 738 (b'\xe5\xba\x94') had 663 occurrences
# merge 484/5000: (368, 185) -> 739 (b'\xe8\xbe\xb9') had 659 occurrences
# merge 485/5000: (298, 187) -> 740 (b'\xe7\x94\xbb') had 659 occurrences
# merge 486/5000: (528, 631) -> 741 (b'\xe9\xa3\x9e\xe8\x88\xb9') had 656 occurrences
# merge 487/5000: (344, 170) -> 742 (b'\xe8\x88\xaa') had 655 occurrences
# merge 488/5000: (336, 154) -> 743 (b'\xe9\x80\x9a') had 654 occurrences
# merge 489/5000: (533, 591) -> 744 (b'\xe8\x88\xb0\xe9\x98\x9f') had 652 occurrences
# merge 490/5000: (231, 138) -> 745 (b'\xe7\x8a') had 652 occurrences
# merge 491/5000: (370, 191) -> 746 (b'\xe7\xba\xbf') had 650 occurrences
# merge 492/5000: (230, 133) -> 747 (b'\xe6\x85') had 646 occurrences
# merge 493/5000: (329, 258) -> 748 (b'\xe6\x9d\xa5\xef\xbc\x8c') had 645 occurrences
# merge 494/5000: (448, 456) -> 749 (b'\xe6\x96\x87\xe6\x98\x8e') had 644 occurrences
# merge 495/5000: (232, 177) -> 750 (b'\xe8\xb1') had 643 occurrences
# merge 496/5000: (506, 188) -> 751 (b'\xe6\xb7\xbc') had 641 occurrences
# merge 497/5000: (307, 175) -> 752 (b'\xe6\x96\xaf') had 641 occurrences
# merge 498/5000: (316, 168) -> 753 (b'\xe5\xb7\xa8') had 636 occurrences
# merge 499/5000: (637, 186) -> 754 (b'\xe5\xbb\xba') had 633 occurrences
# merge 500/5000: (736, 751) -> 755 (b'\xe6\xb1\xaa\xe6\xb7\xbc') had 632 occurrences
# merge 501/5000: (317, 186) -> 756 (b'\xe5\xbc\xba') had 631 occurrences
# merge 502/5000: (406, 176) -> 757 (b'\xe6\x95\xb0') had 630 occurrences
# merge 503/5000: (262, 148) -> 758 (b'\xe4\xba\x94') had 630 occurrences
# merge 504/5000: (375, 157) -> 759 (b'\xe6\x80\x9d') had 627 occurrences
# merge 505/5000: (303, 187) -> 760 (b'\xe5\x87\xbb') had 624 occurrences
# merge 506/5000: (503, 142) -> 761 (b'\xe5\x9f\x8e') had 623 occurrences
# merge 507/5000: (293, 159) -> 762 (b'\xe7\xbb\x9f') had 621 occurrences
# merge 508/5000: (262, 145) -> 763 (b'\xe4\xba\x91') had 621 occurrences
# merge 509/5000: (270, 182) -> 764 (b'\xe5\x8f\xb6') had 618 occurrences
# merge 510/5000: (347, 163) -> 765 (b'\xe8\xa7\xa3') had 616 occurrences
# merge 511/5000: (310, 147) -> 766 (b'\xe6\x89\x93') had 614 occurrences
# merge 512/5000: (356, 258) -> 767 (b'\xe5\x90\x8e\xef\xbc\x8c') had 612 occurrences
# merge 513/5000: (389, 189) -> 768 (b'\xe5\x91\xbd') had 611 occurrences
# merge 514/5000: (317, 149) -> 769 (b'\xe5\xbc\x95') had 610 occurrences
# merge 515/5000: (387, 289) -> 770 (b'\xef\xbc\x9f\xe2\x80\x9d') had 610 occurrences
# merge 516/5000: (232, 131) -> 771 (b'\xe8\x83') had 609 occurrences
# merge 517/5000: (275, 154) -> 772 (b'\xe5\x88\x9a') had 609 occurrences
# merge 518/5000: (267, 145) -> 773 (b'\xe8\xbf\x91') had 607 occurrences
# merge 519/5000: (436, 129) -> 774 (b'\xe6\xb4\x81') had 606 occurrences
# merge 520/5000: (275, 182) -> 775 (b'\xe5\x88\xb6') had 606 occurrences
# merge 521/5000: (404, 172) -> 776 (b'\xe8\xbd\xac') had 604 occurrences
# merge 522/5000: (279, 172) -> 777 (b'\xe5\x90\xac') had 603 occurrences
# merge 523/5000: (279, 136) -> 778 (b'\xe5\x90\x88') had 602 occurrences
# merge 524/5000: (265, 149) -> 779 (b'\xe2\x80\x95') had 601 occurrences
# merge 525/5000: (275, 135) -> 780 (b'\xe5\x88\x87') had 601 occurrences
# merge 526/5000: (358, 133) -> 781 (b'\xe6\x83\x85') had 599 occurrences
# merge 527/5000: (279, 141) -> 782 (b'\xe5\x90\x8d') had 597 occurrences
# merge 528/5000: (463, 190) -> 783 (b'\xe6\x94\xbe') had 597 occurrences
# merge 529/5000: (471, 150) -> 784 (b'\xe5\x8c\x96') had 594 occurrences
# merge 530/5000: (306, 281) -> 785 (b'\xe5\x88\xb0\xe4\xba\x86') had 594 occurrences
# merge 531/5000: (449, 139) -> 786 (b'\xe7\xab\x8b') had 594 occurrences
# merge 532/5000: (436, 187) -> 787 (b'\xe6\xb4\xbb') had 593 occurrences
# merge 533/5000: (266, 285) -> 788 (b'\xe3\x80\x82\xe8\xbf\x99') had 592 occurrences
# merge 534/5000: (349, 371) -> 789 (b'\xe5\x87\xba\xe7\x8e\xb0') had 592 occurrences
# merge 535/5000: (272, 155) -> 790 (b'\xe6\x9c\x9b') had 591 occurrences
# merge 536/5000: (272, 175) -> 791 (b'\xe6\x9c\xaf') had 588 occurrences
# merge 537/5000: (347, 129) -> 792 (b'\xe8\xa7\x81') had 588 occurrences
# merge 538/5000: (487, 292) -> 793 (b'\xe4\xb8\xa4\xe4\xb8\xaa') had 587 occurrences
# merge 539/5000: (366, 184) -> 794 (b'\xe5\xb8\xb8') had 587 occurrences
# merge 540/5000: (525, 190) -> 795 (b'\xe7\x99\xbe') had 583 occurrences
# merge 541/5000: (230, 159) -> 796 (b'\xe6\x9f') had 581 occurrences
# merge 542/5000: (629, 186) -> 797 (b'\xe7\xa4\xba') had 576 occurrences
# merge 543/5000: (331, 292) -> 798 (b'\xe9\x82\xa3\xe4\xb8\xaa') had 575 occurrences
# merge 544/5000: (297, 161) -> 799 (b'\xe6\x9d\xa1') had 574 occurrences
# merge 545/5000: (231, 165) -> 800 (b'\xe7\xa5') had 571 occurrences
# merge 546/5000: (233, 147) -> 801 (b'\xe9\x93') had 571 occurrences
# merge 547/5000: (527, 491) -> 802 (b'\xe9\x83\xa8\xe5\x88\x86') had 571 occurrences
# merge 548/5000: (446, 312) -> 803 (b'\xef\xbc\x8c\xe4\xbb\x96\xe4\xbb\xac') had 570 occurrences
# merge 549/5000: (230, 162) -> 804 (b'\xe6\xa2') had 569 occurrences
# merge 550/5000: (267, 144) -> 805 (b'\xe8\xbf\x90') had 563 occurrences
# merge 551/5000: (275, 146) -> 806 (b'\xe5\x88\x92') had 562 occurrences
# merge 552/5000: (506, 177) -> 807 (b'\xe6\xb7\xb1') had 562 occurrences
# merge 553/5000: (686, 174) -> 808 (b'\xe7\xa1\xae') had 561 occurrences
# merge 554/5000: (320, 139) -> 809 (b'\xe7\x8e\x8b') had 558 occurrences
# merge 555/5000: (229, 150) -> 810 (b'\xe5\x96') had 558 occurrences
# merge 556/5000: (276, 273) -> 811 (b'\xe6\x98\xaf\xe4\xb8\x80') had 558 occurrences
# merge 557/5000: (232, 144) -> 812 (b'\xe8\x90') had 557 occurrences
# merge 558/5000: (293, 147) -> 813 (b'\xe7\xbb\x93') had 556 occurrences
# merge 559/5000: (270, 163) -> 814 (b'\xe5\x8f\xa3') had 556 occurrences
# merge 560/5000: (233, 166) -> 815 (b'\xe9\xa6') had 556 occurrences
# merge 561/5000: (404, 187) -> 816 (b'\xe8\xbd\xbb') had 555 occurrences
# merge 562/5000: (503, 186) -> 817 (b'\xe5\x9f\xba') had 554 occurrences
# merge 563/5000: (360, 312) -> 818 (b'\xe4\xbd\xa0\xe4\xbb\xac') had 554 occurrences
# merge 564/5000: (233, 148) -> 819 (b'\xe9\x94') had 551 occurrences
# merge 565/5000: (230, 141) -> 820 (b'\xe6\x8d') had 550 occurrences
# merge 566/5000: (750, 161) -> 821 (b'\xe8\xb1\xa1') had 548 occurrences
# merge 567/5000: (293, 153) -> 822 (b'\xe7\xbb\x99') had 548 occurrences
# merge 568/5000: (493, 186) -> 823 (b'\xe6\x99\xba') had 547 occurrences
# merge 569/5000: (287, 142) -> 824 (b'\xe4\xb9\x8e') had 547 occurrences
# merge 570/5000: (320, 175) -> 825 (b'\xe7\x8e\xaf') had 546 occurrences
# merge 571/5000: (264, 141) -> 826 (b'\xe4\xbb\x8d') had 545 occurrences
# merge 572/5000: (274, 149) -> 827 (b'\xe4\xbd\x95') had 544 occurrences
# merge 573/5000: (258, 294) -> 828 (b'\xef\xbc\x8c\xe4\xb8\x8d') had 543 occurrences
# merge 574/5000: (343, 191) -> 829 (b'\xe7\xa9\xbf') had 542 occurrences
# merge 575/5000: (291, 273) -> 830 (b'\xe6\x9c\x89\xe4\xb8\x80') had 541 occurrences
# merge 576/5000: (359, 145) -> 831 (b'\xe7\xa7\x91') had 540 occurrences
# merge 577/5000: (264, 182) -> 832 (b'\xe4\xbb\xb6') had 540 occurrences
# merge 578/5000: (286, 145) -> 833 (b'\xe5\xb0\x91') had 540 occurrences
# merge 579/5000: (233, 170) -> 834 (b'\xe9\xaa') had 540 occurrences
# merge 580/5000: (258, 460) -> 835 (b'\xef\xbc\x8c\xe5\xae\x83') had 537 occurrences
# merge 581/5000: (560, 693) -> 836 (b'\xe4\xbf\xa1\xe6\x81\xaf') had 536 occurrences
# merge 582/5000: (232, 153) -> 837 (b'\xe8\x99') had 536 occurrences
# merge 583/5000: (703, 690) -> 838 (b'\xe4\xb8\x9c\xe8\xa5\xbf') had 534 occurrences
# merge 584/5000: (685, 151) -> 839 (b'\xe6\x9a\x97') had 532 occurrences
# merge 585/5000: (232, 138) -> 840 (b'\xe8\x8a') had 531 occurrences
# merge 586/5000: (405, 185) -> 841 (b'\xe7\x89\xb9') had 531 occurrences
# merge 587/5000: (307, 176) -> 842 (b'\xe6\x96\xb0') had 530 occurrences
# merge 588/5000: (368, 190) -> 843 (b'\xe8\xbe\xbe') had 530 occurrences
# merge 589/5000: (464, 356) -> 844 (b'\xe6\x9c\x80\xe5\x90\x8e') had 529 occurrences
# merge 590/5000: (485, 312) -> 845 (b'\xef\xbc\x8c\xe6\x88\x91\xe4\xbb\xac') had 528 occurrences
# merge 591/5000: (347, 130) -> 846 (b'\xe8\xa7\x82') had 528 occurrences
# merge 592/5000: (351, 129) -> 847 (b'\xe8\x80\x81') had 525 occurrences
# merge 593/5000: (391, 371) -> 848 (b'\xe5\x8f\x91\xe7\x8e\xb0') had 525 occurrences
# merge 594/5000: (325, 164) -> 849 (b'\xe8\xae\xa4') had 521 occurrences
# merge 595/5000: (375, 129) -> 850 (b'\xe6\x80\x81') had 519 occurrences
# merge 596/5000: (231, 180) -> 851 (b'\xe7\xb4') had 518 occurrences
# merge 597/5000: (745, 182) -> 852 (b'\xe7\x8a\xb6') had 518 occurrences
# merge 598/5000: (311, 261) -> 853 (b'\xe4\xb8\x8a\xe7\x9a\x84') had 518 occurrences
# merge 599/5000: (335, 168) -> 854 (b'\xe9\x97\xa8') had 517 occurrences
# merge 600/5000: (366, 166) -> 855 (b'\xe5\xb8\xa6') had 517 occurrences
# merge 601/5000: (282, 137) -> 856 (b'\xe5\xae\x89') had 516 occurrences
# merge 602/5000: (309, 151) -> 857 (b'\xe5\xad\x97') had 515 occurrences
# merge 603/5000: (342, 135) -> 858 (b'\xe6\xa0\x87') had 515 occurrences
# merge 604/5000: (338, 182) -> 859 (b'\xe5\xb9\xb6') had 515 occurrences
# merge 605/5000: (362, 159) -> 860 (b'\xe5\x8e\x9f') had 510 occurrences
# merge 606/5000: (290, 165) -> 861 (b'\xe8\xaf\xa5') had 510 occurrences
# merge 607/5000: (649, 136) -> 862 (b'\xe6\xb6\x88') had 510 occurrences
# merge 608/5000: (341, 597) -> 863 (b'\xe8\xaf\xb4\xef\xbc\x9a\xe2\x80\x9c') had 510 occurrences
# merge 609/5000: (448, 774) -> 864 (b'\xe6\x96\x87\xe6\xb4\x81') had 509 occurrences
# merge 610/5000: (270, 141) -> 865 (b'\xe5\x8f\x8d') had 508 occurrences
# merge 611/5000: (521, 145) -> 866 (b'\xe7\xac\x91') had 508 occurrences
# merge 612/5000: (504, 291) -> 867 (b'\xe6\x89\x80\xe6\x9c\x89') had 507 occurrences
# merge 613/5000: (274, 142) -> 868 (b'\xe4\xbd\x8e') had 507 occurrences
# merge 614/5000: (295, 165) -> 869 (b'\xe6\x97\xa5') had 505 occurrences
# merge 615/5000: (257, 155) -> 870 (b'\xef\xbc\x9b') had 505 occurrences
# merge 616/5000: (314, 131) -> 871 (b'\xe5\x8d\x83') had 504 occurrences
# merge 617/5000: (281, 266) -> 872 (b'\xe4\xba\x86\xe3\x80\x82') had 504 occurrences
# merge 618/5000: (604, 137) -> 873 (b'\xe7\xad\x89') had 503 occurrences
# merge 619/5000: (580, 138) -> 874 (b'\xe8\xb6\x8a') had 503 occurrences
# merge 620/5000: (283, 131) -> 875 (b'\xe5\x85\x83') had 503 occurrences
# merge 621/5000: (347, 134) -> 876 (b'\xe8\xa7\x86') had 501 occurrences
# merge 622/5000: (381, 426) -> 877 (b'\xe7\xa9\xba\xe9\x97\xb4') had 500 occurrences
# merge 623/5000: (273, 447) -> 878 (b'\xe4\xb8\x80\xe6\xa0\xb7') had 499 occurrences
# merge 624/5000: (305, 174) -> 879 (b'\xe5\xbe\xae') had 497 occurrences
# merge 625/5000: (374, 187) -> 880 (b'\xe6\xad\xbb') had 496 occurrences
# merge 626/5000: (475, 419) -> 881 (b'\xe8\xbf\x9b\xe8\xa1\x8c') had 495 occurrences
# merge 627/5000: (229, 158) -> 882 (b'\xe5\x9e') had 495 occurrences
# merge 628/5000: (486, 725) -> 883 (b'\xe5\xbc\x80\xe5\xa7\x8b') had 494 occurrences
# merge 629/5000: (283, 136) -> 884 (b'\xe5\x85\x88') had 494 occurrences
# merge 630/5000: (412, 171) -> 885 (b'\xe5\xa3\xab') had 494 occurrences
# merge 631/5000: (524, 133) -> 886 (b'\xe6\xb8\x85') had 493 occurrences
# merge 632/5000: (300, 437) -> 887 (b'\xef\xbc\x8c\xe5\x83\x8f') had 493 occurrences
# merge 633/5000: (517, 190) -> 888 (b'\xe9\x9a\xbe') had 492 occurrences
# merge 634/5000: (319, 180) -> 889 (b'\xe5\x9b\xb4') had 492 occurrences
# merge 635/5000: (258, 379) -> 890 (b'\xef\xbc\x8c\xe4\xb9\x9f') had 491 occurrences
# merge 636/5000: (230, 174) -> 891 (b'\xe6\xae') had 491 occurrences
# merge 637/5000: (571, 151) -> 892 (b'\xe7\xae\x97') had 488 occurrences
# merge 638/5000: (404, 166) -> 893 (b'\xe8\xbd\xa6') had 487 occurrences
# merge 639/5000: (325, 184) -> 894 (b'\xe8\xae\xb8') had 487 occurrences
# merge 640/5000: (513, 762) -> 895 (b'\xe7\xb3\xbb\xe7\xbb\x9f') had 487 occurrences
# merge 641/5000: (472, 152) -> 896 (b'\xe9\xa2\x98') had 484 occurrences
# merge 642/5000: (431, 143) -> 897 (b'\xe6\xaf\x8f') had 483 occurrences
# merge 643/5000: (327, 261) -> 898 (b'\xe5\xa4\xa7\xe7\x9a\x84') had 482 occurrences
# merge 644/5000: (128, 791) -> 899 (b'\x80\xe6\x9c\xaf') had 481 occurrences
# merge 645/5000: (675, 148) -> 900 (b'\xe8\x81\x94') had 479 occurrences
# merge 646/5000: (465, 276) -> 901 (b'\xe8\xbf\x98\xe6\x98\xaf') had 478 occurrences
# merge 647/5000: (230, 161) -> 902 (b'\xe6\xa1') had 477 occurrences
# merge 648/5000: (319, 160) -> 903 (b'\xe5\x9b\xa0') had 475 occurrences
# merge 649/5000: (548, 168) -> 904 (b'\xe8\xb4\xa8') had 475 occurrences
# merge 650/5000: (232, 163) -> 905 (b'\xe8\xa3') had 475 occurrences
# merge 651/5000: (627, 806) -> 906 (b'\xe8\xae\xa1\xe5\x88\x92') had 474 occurrences
# merge 652/5000: (444, 130) -> 907 (b'\xe5\xb1\x82') had 474 occurrences
# merge 653/5000: (764, 864) -> 908 (b'\xe5\x8f\xb6\xe6\x96\x87\xe6\xb4\x81') had 472 occurrences
# ...
# merge 4823/5000: (398, 767) -> 5078 (b'\xe4\xbb\xa5\xe5\x90\x8e\xef\xbc\x8c') had 29 occurrences
# merge 4824/5000: (378, 708) -> 5079 (b'\xe5\xa4\xaa\xe5\xb9\xb3') had 29 occurrences
# merge 4825/5000: (435, 140) -> 5080 (b'\xe9\x99\x8c') had 29 occurrences
# merge 4826/5000: (705, 3885) -> 5081 (b'\xe7\x99\xbd\xe6\xb2\x90') had 29 occurrences
# merge 4827/5000: (5081, 619) -> 5082 (b'\xe7\x99\xbd\xe6\xb2\x90\xe9\x9c') had 29 occurrences
# merge 4828/5000: (5082, 150) -> 5083 (b'\xe7\x99\xbd\xe6\xb2\x90\xe9\x9c\x96') had 29 occurrences
# merge 4829/5000: (663, 1208) -> 5084 (b'\xe5\x85\xac\xe8\xb7\xaf') had 29 occurrences
# merge 4830/5000: (1626, 773) -> 5085 (b'\xe9\x9d\xa0\xe8\xbf\x91') had 29 occurrences
# merge 4831/5000: (618, 515) -> 5086 (b'\xe5\xb0\x86\xe8\xa2\xab') had 29 occurrences
# merge 4832/5000: (302, 341) -> 5087 (b'\xe4\xbb\x96\xe8\xaf\xb4') had 29 occurrences
# merge 4833/5000: (1175, 185) -> 5088 (b'\xe5\xa6\xb9') had 29 occurrences
# merge 4834/5000: (308, 1002) -> 5089 (b'\xe4\xb8\xad\xe6\x96\xad') had 29 occurrences
# merge 4835/5000: (1240, 1009) -> 5090 (b'\xe5\x80\x99\xe9\x80\x89') had 29 occurrences
# merge 4836/5000: (1578, 589) -> 5091 (b'\xe9\xa2\x9c\xe8\x89\xb2') had 29 occurrences
# merge 4837/5000: (3463, 421) -> 5092 (b'\xe5\x8f\xaf\xe8\xa7\x81\xe5\x85\x89') had 29 occurrences
# merge 4838/5000: (1100, 526) -> 5093 (b'\xe6\x84\x9f\xe8\xa7\x89\xe8\x87\xaa\xe5\xb7\xb1') had 29 occurrences
# merge 4839/5000: (1733, 965) -> 5094 (b'\xe5\xae\x81\xe9\x9d\x99') had 29 occurrences
# merge 4840/5000: (335, 178) -> 5095 (b'\xe9\x97\xb2') had 29 occurrences
# merge 4841/5000: (708, 1125) -> 5096 (b'\xe5\xb9\xb3\xe5\x8f\xb0') had 29 occurrences
# merge 4842/5000: (1716, 589) -> 5097 (b'\xe9\xbb\x84\xe8\x89\xb2') had 29 occurrences
# merge 4843/5000: (229, 1544) -> 5098 (b'\xe5\x83\xbb') had 29 occurrences
# merge 4844/5000: (266, 1853) -> 5099 (b'\xe3\x80\x82\xe5\xaf\xb9\xe4\xba\x8e') had 29 occurrences
# merge 4845/5000: (294, 294) -> 5100 (b'\xe4\xb8\x8d\xe4\xb8\x8d') had 29 occurrences
# merge 4846/5000: (269, 143) -> 5101 (b'\xe5\xa4\x8f') had 29 occurrences
# merge 4847/5000: (1257, 1224) -> 5102 (b'\xe5\x85\xb7\xe5\xa4\x87') had 29 occurrences
# merge 4848/5000: (408, 513) -> 5103 (b'\xe4\xbd\x93\xe7\xb3\xbb') had 29 occurrences
# merge 4849/5000: (1566, 491) -> 5104 (b'\xe5\x85\x85\xe5\x88\x86') had 29 occurrences
# merge 4850/5000: (603, 1052) -> 5105 (b'\xe4\xb8\x89\xe4\xbd\x93\xe9\x97\xae\xe9\xa2\x98') had 29 occurrences
# merge 4851/5000: (532, 308) -> 5106 (b'\xe4\xb8\x96\xe7\x95\x8c\xe4\xb8\xad') had 29 occurrences
# merge 4852/5000: (1977, 299) -> 5107 (b'\xe6\x99\xae\xe9\x80\x9a\xe4\xba\xba') had 29 occurrences
# merge 4853/5000: (933, 2641) -> 5108 (b'\xe6\x95\xb4\xe9\xbd\x90') had 29 occurrences
# merge 4854/5000: (392, 180) -> 5109 (b'\xe7\x90\xb4') had 29 occurrences
# merge 4855/5000: (1552, 176) -> 5110 (b'\xe9\xa5\xb0') had 29 occurrences
# merge 4856/5000: (1305, 298) -> 5111 (b'\xe4\xbc\x8a\xe7\x94') had 29 occurrences
# merge 4857/5000: (5111, 184) -> 5112 (b'\xe4\xbc\x8a\xe7\x94\xb8') had 29 occurrences
# merge 4858/5000: (5112, 2211) -> 5113 (b'\xe4\xbc\x8a\xe7\x94\xb8\xe5\x9b\xad') had 29 occurrences
# merge 4859/5000: (1172, 737) -> 5114 (b'\xe5\x8c\xba\xe5\x88\xab') had 29 occurrences
# merge 4860/5000: (756, 4893) -> 5115 (b'\xe5\xbc\xba\xe4\xba\x92\xe4\xbd\x9c\xe7\x94\xa8\xe5\x8a\x9b') had 29 occurrences
# merge 4861/5000: (304, 967) -> 5116 (b'\xe3\x80\x82\n\xe3\x80\x80\xe3\x80\x80\xe6\x99\xba\xe5\xad\x90') had 29 occurrences
# merge 4862/5000: (4875, 79) -> 5117 (b'ETO') had 29 occurrences
# merge 4863/5000: (4089, 597) -> 5118 (b'\xe7\xa0\xb4\xe5\xa3\x81\xe4\xba\xba\xe4\xba\x8c\xe5\x8f\xb7\xef\xbc\x9a\xe2\x80\x9c') had 29 occurrences
# merge 4864/5000: (630, 1952) -> 5119 (b'\xe8\xba\xab\xe4\xbb\xbd') had 29 occurrences
# merge 4865/5000: (1222, 1158) -> 5120 (b'\xe5\xaf\x86\xe9\x9b\x86') had 29 occurrences
# merge 4866/5000: (1090, 1017) -> 5121 (b'\xe6\x9c\xa8\xe5\x8d\xab') had 29 occurrences
# merge 4867/5000: (1643, 179) -> 5122 (b'\xe8\x9e\xb3') had 29 occurrences
# merge 4868/5000: (5122, 1643) -> 5123 (b'\xe8\x9e\xb3\xe8\x9e') had 29 occurrences
# merge 4869/5000: (5123, 130) -> 5124 (b'\xe8\x9e\xb3\xe8\x9e\x82') had 29 occurrences
# merge 4870/5000: (5124, 709) -> 5125 (b'\xe8\x9e\xb3\xe8\x9e\x82\xe2\x80\x9d\xe5\x8f\xb7') had 29 occurrences
# merge 4871/5000: (1068, 690) -> 5126 (b'\xe8\x93\x9d\xe8\xa5\xbf') had 29 occurrences
# merge 4872/5000: (2325, 1085) -> 5127 (b'\xe8\x89\xbeAA') had 29 occurrences
# merge 4873/5000: (261, 1128) -> 5128 (b'\xe7\x9a\x84\xe5\xad\xa9\xe5\xad\x90') had 28 occurrences
# merge 4874/5000: (290, 151) -> 5129 (b'\xe8\xaf\x97') had 28 occurrences
# merge 4875/5000: (301, 129) -> 5130 (b'\xe7\x9c\x81') had 28 occurrences
# merge 4876/5000: (316, 167) -> 5131 (b'\xe5\xb7\xa7') had 28 occurrences
# merge 4877/5000: (610, 799) -> 5132 (b'\xe4\xba\x86\xe4\xb8\x80\xe6\x9d\xa1') had 28 occurrences
# merge 4878/5000: (379, 1317) -> 5133 (b'\xe4\xb9\x9f\xe5\x8f\xaa\xe8\x83\xbd') had 28 occurrences
# merge 4879/5000: (4503, 1384) -> 5134 (b'\xe5\xbe\x80\xe4\xba\x8b\xe3\x80\x8b') had 28 occurrences
# merge 4880/5000: (331, 299) -> 5135 (b'\xe9\x82\xa3\xe4\xba\xba') had 28 occurrences
# merge 4881/5000: (359, 129) -> 5136 (b'\xe7\xa7\x81') had 28 occurrences
# merge 4882/5000: (386, 2723) -> 5137 (b'\xe4\xb8\x8b\xe5\x8d\x88') had 28 occurrences
# merge 4883/5000: (303, 145) -> 5138 (b'\xe5\x87\x91') had 28 occurrences
# merge 4884/5000: (2102, 568) -> 5139 (b'\xe7\x8e\xa9\xe6\x84\x8f') had 28 occurrences
# merge 4885/5000: (756, 584) -> 5140 (b'\xe5\xbc\xba\xe5\xba\xa6') had 28 occurrences
# merge 4886/5000: (273, 495) -> 5141 (b'\xe4\xb8\x80\xe6\x8a\x8a') had 28 occurrences
# merge 4887/5000: (1888, 3566) -> 5142 (b'\xe8\xbf\xb7\xe6\x83\x91') had 28 occurrences
# merge 4888/5000: (697, 386) -> 5143 (b'\xe5\x9b\x9b\xe4\xb8\x8b') had 28 occurrences
# merge 4889/5000: (391, 1259) -> 5144 (b'\xe5\x8f\x91\xe8\xa8\x80') had 28 occurrences
# merge 4890/5000: (306, 1403) -> 5145 (b'\xe5\x88\xb0\xe5\xba\x95') had 28 occurrences
# merge 4891/5000: (1587, 141) -> 5146 (b'\xe7\x8f\x8d') had 28 occurrences
# merge 4892/5000: (363, 1563) -> 5147 (b'\xe5\xb0\xb1\xe5\x9c\xa8\xe8\xbf\x99') had 28 occurrences
# merge 4893/5000: (4515, 377) -> 5148 (b'\xe6\xb7\xb9\xe6\xb2\xa1') had 28 occurrences
# merge 4894/5000: (1018, 349) -> 5149 (b'\xe9\x80\x8f\xe5\x87\xba') had 28 occurrences
# merge 4895/5000: (499, 1462) -> 5150 (b'\xe4\xbb\x80\xe4\xb9\x88\xe6\x97\xb6\xe5\x80\x99') had 28 occurrences
# merge 4896/5000: (2582, 2599) -> 5151 (b'\xe7\x97\x9b\xe8\x8b\xa6') had 28 occurrences
# merge 4897/5000: (734, 673) -> 5152 (b'\xe8\xbf\x99\xe6\xa0\xb7\xe5\x81\x9a') had 28 occurrences
# merge 4898/5000: (604, 190) -> 5153 (b'\xe7\xad\xbe') had 28 occurrences
# merge 4899/5000: (856, 1427) -> 5154 (b'\xe5\xae\x89\xe6\x8e\x92') had 28 occurrences
# merge 4900/5000: (534, 182) -> 5155 (b'\xe5\x81\xb6') had 28 occurrences
# merge 4901/5000: (914, 1573) -> 5156 (b'\xe9\xa2\x97\xe6\x98\x9f\xe6\x98\x9f') had 28 occurrences
# merge 4902/5000: (2281, 258) -> 5157 (b'\xe7\x9b\xb8\xe6\xaf\x94\xef\xbc\x8c') had 28 occurrences
# merge 4903/5000: (1481, 903) -> 5158 (b'\xe7\x88\xb1\xe5\x9b\xa0') had 28 occurrences
# merge 4904/5000: (5158, 3401) -> 5159 (b'\xe7\x88\xb1\xe5\x9b\xa0\xe6\x96\xaf\xe5\x9d\xa6') had 28 occurrences
# merge 4905/5000: (1092, 607) -> 5160 (b'\xe6\x94\xb6\xe5\x9b\x9e') had 28 occurrences
# merge 4906/5000: (569, 285) -> 5161 (b'\xef\xbc\x8c\xe2\x80\x9c\xe8\xbf\x99') had 28 occurrences
# merge 4907/5000: (1908, 166) -> 5162 (b'\xef\xbc\x8c\xe5\xb8\xa6') had 28 occurrences
# merge 4908/5000: (663, 1253) -> 5163 (b'\xe5\x85\xac\xe5\xb8\x83') had 28 occurrences
# merge 4909/5000: (58, 51) -> 5164 (b':3') had 28 occurrences
# merge 4910/5000: (304, 539) -> 5165 (b'\xe3\x80\x82\n\xe3\x80\x80\xe3\x80\x80\xe7\x8e\xb0\xe5\x9c\xa8') had 28 occurrences
# merge 4911/5000: (283, 129) -> 5166 (b'\xe5\x85\x81') had 28 occurrences
# merge 4912/5000: (348, 383) -> 5167 (b'\xe7\x9c\x8b\xe8\xbf\x87') had 28 occurrences
# merge 4913/5000: (261, 2474) -> 5168 (b'\xe7\x9a\x84\xe8\xbe\xb9\xe7\xbc\x98') had 28 occurrences
# merge 4914/5000: (467, 261) -> 5169 (b'\xe5\xa4\x9a\xe7\x9a\x84') had 28 occurrences
# merge 4915/5000: (149, 1230) -> 5170 (b'\x95\xe8\xbf\xb9') had 28 occurrences
# merge 4916/5000: (419, 261) -> 5171 (b'\xe8\xa1\x8c\xe7\x9a\x84') had 28 occurrences
# merge 4917/5000: (2792, 311) -> 5172 (b'\xe7\x9a\x84\xe8\x84\xb8\xe4\xb8\x8a') had 28 occurrences
# merge 4918/5000: (614, 482) -> 5173 (b'\xe7\x9a\x84\xe4\xb8\x80\xe7\xa7\x8d') had 28 occurrences
# merge 4919/5000: (2925, 133) -> 5174 (b'\xe7\x9a\x84\xe7\x97\x85') had 28 occurrences
# merge 4920/5000: (970, 1288) -> 5175 (b'\xe6\xa0\xb9\xe6\x8d\xae') had 28 occurrences
# merge 4921/5000: (258, 403) -> 5176 (b'\xef\xbc\x8c\xe4\xb8\x89') had 28 occurrences
# merge 4922/5000: (1789, 421) -> 5177 (b'\xe6\xbf\x80\xe5\x85\x89') had 28 occurrences
# merge 4923/5000: (464, 566) -> 5178 (b'\xe6\x9c\x80\xe5\xa5\xbd') had 28 occurrences
# merge 4924/5000: (976, 797) -> 5179 (b'\xe6\x8f\x90\xe7\xa4\xba') had 28 occurrences
# merge 4925/5000: (261, 869) -> 5180 (b'\xe7\x9a\x84\xe6\x97\xa5') had 28 occurrences
# merge 4926/5000: (430, 739) -> 5181 (b'\xe5\xa4\xa9\xe8\xbe\xb9') had 28 occurrences
# merge 4927/5000: (281, 672) -> 5182 (b'\xe4\xba\x86\xef\xbc\x9f\xe2\x80\x9d\n\xe3\x80\x80\xe3\x80\x80\xe2\x80\x9c') had 28 occurrences
# merge 4928/5000: (2039, 132) -> 5183 (b'\xef\xbc\x8c\xe5\xba\x84') had 28 occurrences
# merge 4929/5000: (545, 613) -> 5184 (b'\xe6\x97\xa0\xe5\xa3\xb0') had 28 occurrences
# merge 4930/5000: (496, 1840) -> 5185 (b'\xe9\x95\xbf\xe9\x95\xbf\xe7\x9a\x84') had 28 occurrences
# merge 4931/5000: (261, 1838) -> 5186 (b'\xe7\x9a\x84\xe5\xbb\xba\xe7\xad\x91') had 28 occurrences
# merge 4932/5000: (1542, 276) -> 5187 (b'\xe6\x98\xbe\xe7\x84\xb6\xe6\x98\xaf') had 28 occurrences
# merge 4933/5000: (4523, 408) -> 5188 (b'\xe4\xb8\xba\xe4\xb8\x80\xe4\xbd\x93') had 28 occurrences
# merge 4934/5000: (231, 133) -> 5189 (b'\xe7\x85') had 28 occurrences
# merge 4935/5000: (329, 785) -> 5190 (b'\xe6\x9d\xa5\xe5\x88\xb0\xe4\xba\x86') had 28 occurrences
# merge 4936/5000: (272, 151) -> 5191 (b'\xe6\x9c\x97') had 28 occurrences
# merge 4937/5000: (870, 384) -> 5192 (b'\xef\xbc\x9b\xe4\xbd\x86') had 28 occurrences
# merge 4938/5000: (499, 447) -> 5193 (b'\xe4\xbb\x80\xe4\xb9\x88\xe6\xa0\xb7') had 28 occurrences
# merge 4939/5000: (646, 746) -> 5194 (b'\xe7\x9b\xb4\xe7\xba\xbf') had 28 occurrences
# merge 4940/5000: (398, 329) -> 5195 (b'\xe4\xbb\xa5\xe6\x9d\xa5') had 28 occurrences
# merge 4941/5000: (281, 644) -> 5196 (b'\xe4\xba\x86\xef\xbc\x8c\xe5\xa5\xb9') had 28 occurrences
# merge 4942/5000: (1797, 718) -> 5197 (b'\xe5\xb9\xb8\xe5\xad\x98') had 28 occurrences
# merge 4943/5000: (261, 2369) -> 5198 (b'\xe7\x9a\x84\xe5\xbd\xb1\xe5\x93\x8d') had 28 occurrences
# merge 4944/5000: (851, 171) -> 5199 (b'\xe7\xb4\xab') had 28 occurrences
# merge 4945/5000: (873, 457) -> 5200 (b'\xe7\xad\x89\xe4\xba\x8e') had 28 occurrences
# merge 4946/5000: (860, 1163) -> 5201 (b'\xe5\x8e\x9f\xe5\x88\x99') had 28 occurrences
# merge 4947/5000: (258, 2048) -> 5202 (b'\xef\xbc\x8c\xe8\x87\xb3\xe5\xb0\x91') had 28 occurrences
# merge 4948/5000: (1160, 131) -> 5203 (b'\xe5\x8b\x83') had 28 occurrences
# merge 4949/5000: (1711, 450) -> 5204 (b'\xe4\xb8\xbe\xe8\xb5\xb7') had 28 occurrences
# merge 4950/5000: (1325, 323) -> 5205 (b'\xef\xbc\x8c\xe5\xbd\x93\xe6\x97\xb6') had 28 occurrences
# merge 4951/5000: (777, 785) -> 5206 (b'\xe5\x90\xac\xe5\x88\xb0\xe4\xba\x86') had 28 occurrences
# merge 4952/5000: (5080, 429) -> 5207 (b'\xe9\x99\x8c\xe7\x94\x9f') had 28 occurrences
# merge 4953/5000: (2436, 693) -> 5208 (b'\xe5\x8f\xb9\xe6\x81\xaf') had 28 occurrences
# merge 4954/5000: (393, 593) -> 5209 (b'\xe5\xaf\xb9\xe4\xba\xba\xe7\xb1\xbb') had 28 occurrences
# merge 4955/5000: (925, 188) -> 5210 (b'\xe6\x92\xbc') had 28 occurrences
# merge 4956/5000: (537, 1115) -> 5211 (b'\xe4\xb9\x8b\xe6\x89\x80\xe4\xbb\xa5') had 28 occurrences
# merge 4957/5000: (3014, 2122) -> 5212 (b'\xe5\x80\x9f\xe5\x8a\xa9') had 28 occurrences
# merge 4958/5000: (1069, 797) -> 5213 (b'\xe5\xb1\x95\xe7\xa4\xba') had 28 occurrences
# merge 4959/5000: (321, 567) -> 5214 (b'\xe5\x9c\xb0\xe9\x97\xae') had 28 occurrences
# merge 4960/5000: (3712, 2506) -> 5215 (b'\xe7\x9a\x84\xe8\x8c\x83\xe5\x9b\xb4') had 28 occurrences
# merge 4961/5000: (622, 2459) -> 5216 (b'\xe6\x8e\xa5\xe6\x94\xb6\xe5\x88\xb0') had 28 occurrences
# merge 4962/5000: (273, 866) -> 5217 (b'\xe4\xb8\x80\xe7\xac\x91') had 28 occurrences
# merge 4963/5000: (467, 292) -> 5218 (b'\xe5\xa4\x9a\xe4\xb8\xaa') had 28 occurrences
# merge 4964/5000: (336, 184) -> 5219 (b'\xe9\x80\xb8') had 28 occurrences
# merge 4965/5000: (487, 871) -> 5220 (b'\xe4\xb8\xa4\xe5\x8d\x83') had 28 occurrences
# merge 4966/5000: (2348, 146) -> 5221 (b'\xe6\x87\x92') had 28 occurrences
# merge 4967/5000: (619, 158) -> 5222 (b'\xe9\x9c\x9e') had 28 occurrences
# merge 4968/5000: (319, 176) -> 5223 (b'\xe5\x9b\xb0') had 28 occurrences
# merge 4969/5000: (1012, 3889) -> 5224 (b'\xe9\x9b\xb7\xe6\x94\xbf\xe5\xa7\x94') had 28 occurrences
# merge 4970/5000: (258, 1489) -> 5225 (b'\xef\xbc\x8c\xe4\xb8\xba\xe4\xba\x86') had 28 occurrences
# merge 4971/5000: (683, 1208) -> 5226 (b'\xe7\x94\xb5\xe8\xb7\xaf') had 28 occurrences
# merge 4972/5000: (2206, 1669) -> 5227 (b'\xe7\x94\xb5\xe7\xa3\x81\xe8\xbe\x90\xe5\xb0\x84') had 28 occurrences
# merge 4973/5000: (466, 168) -> 5228 (b'\xe6\x81\xa8') had 28 occurrences
# merge 4974/5000: (1331, 152) -> 5229 (b'\xe7\xbf\x98') had 28 occurrences
# merge 4975/5000: (399, 313) -> 5230 (b'\xef\xbc\x9a\xe6\x88\x91') had 28 occurrences
# merge 4976/5000: (436, 155) -> 5231 (b'\xe6\xb4\x9b') had 28 occurrences
# merge 4977/5000: (258, 1324) -> 5232 (b'\xef\xbc\x8c\xe8\x82\xaf\xe5\xae\x9a') had 28 occurrences
# merge 4978/5000: (2477, 1450) -> 5233 (b'\xe9\x87\x87\xe5\x8f\x96') had 28 occurrences
# merge 4979/5000: (1136, 426) -> 5234 (b'\xe6\x9c\x9f\xe9\x97\xb4') had 28 occurrences
# merge 4980/5000: (673, 281) -> 5235 (b'\xe5\x81\x9a\xe4\xba\x86') had 28 occurrences
# merge 4981/5000: (803, 373) -> 5236 (b'\xef\xbc\x8c\xe4\xbb\x96\xe4\xbb\xac\xe9\x83\xbd') had 28 occurrences
# merge 4982/5000: (332, 160) -> 5237 (b'\xe5\xbf\xa0') had 28 occurrences
# merge 4983/5000: (2206, 1046) -> 5238 (b'\xe7\x94\xb5\xe7\xa3\x81\xe6\xb3\xa2') had 28 occurrences
# merge 4984/5000: (231, 176) -> 5239 (b'\xe7\xb0') had 28 occurrences
# merge 4985/5000: (908, 399) -> 5240 (b'\xe5\x8f\xb6\xe6\x96\x87\xe6\xb4\x81\xef\xbc\x9a') had 28 occurrences
# merge 4986/5000: (483, 163) -> 5241 (b'\xe7\x9a\x84\xe8\xa3') had 28 occurrences
# merge 4987/5000: (1701, 929) -> 5242 (b'\xe5\x88\xb0\xe8\xbe\xbe\xe5\xa4\xaa\xe9\x98\xb3\xe7\xb3\xbb') had 28 occurrences
# merge 4988/5000: (286, 137) -> 5243 (b'\xe5\xb0\x89') had 28 occurrences
# merge 4989/5000: (900, 5007) -> 5244 (b'\xe8\x81\x94\xe5\xb8\xad\xe4\xbc\x9a\xe8\xae\xae') had 28 occurrences
# merge 4990/5000: (369, 2970) -> 5245 (b'\xe3\x80\x82\xe2\x80\x9d\n\xe3\x80\x80\xe3\x80\x80\xe5\xad\x97\xe5\xb9\x95\xef\xbc\x9a') had 28 occurrences
# merge 4991/5000: (1575, 2126) -> 5246 (b'\xe5\x9c\x86\xe6\x9f\xb1') had 28 occurrences
# merge 4992/5000: (420, 191) -> 5247 (b'\xe7\x9f\xbf') had 28 occurrences
# merge 4993/5000: (495, 615) -> 5248 (b'\xe6\x8a\x8a\xe6\x89\x8b') had 28 occurrences
# merge 4994/5000: (514, 2715) -> 5249 (b'\xe7\xbd\x97\xe8\x80\x81\xe5\xb8\x88') had 28 occurrences
# merge 4995/5000: (4987, 1022) -> 5250 (b'\xe7\x9a\x84\xe8\x83\x9c\xe5\x88\xa9') had 28 occurrences
# merge 4996/5000: (2849, 308) -> 5251 (b'\xe5\xa4\xb1\xe9\x87\x8d\xe4\xb8\xad') had 28 occurrences
# merge 4997/5000: (1590, 856) -> 5252 (b'\xe6\xb2\xbb\xe5\xae\x89') had 28 occurrences
# merge 4998/5000: (498, 261) -> 5253 (b'\xe7\xa8\x8b\xe5\xbf\x83\xe7\x9a\x84') had 28 occurrences
# merge 4999/5000: (4770, 841) -> 5254 (b'\xe9\x9f\xa6\xe6\x96\xaf\xe7\x89\xb9') had 28 occurrences
# merge 5000/5000: (154, 1946) -> 5255 (b'\x9a\xe5\xb2\xa9') had 28 occurrences
# Training took 970.94 seconds
# [755, 545, 333, 136, 321, 4276, 258, 2840, 522, 618, 647, 505, 760, 628, 1355, 691, 266]
# 最像是�
